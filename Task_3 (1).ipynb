# %% [markdown]
# # Чтение и запись данных, часть 2
#
# ## Практическая работа
#
# ### Описание практической работы и формат сдачи
#
# Выполните предложенные задачи: сохраните блокнот отдельно себе на диск и после этого пишите код в ячейках под задачами. Итоговый файл в формате `.ipynb` (файл Jupyter Notebook) загрузите в личный кабинет и отправьте на проверку.

# %% [markdown]
# ### Задача 1
#
# Используя сервис WeatherAPI, получите прогноз погоды в Лондоне на следующие 2 дня. Ответ преобразуйте к типу JSON.

# %%
import urllib.request as req
import json

API_KEY = "83976e6bce8d4fe8980142043251509"  # нужно получить на weatherapi.com
city = "London"
days = 2

url = f"http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q={city}&days={days}"

session = req.urlopen(url)
response = session.read().decode()
session.close()
data = json.loads(response)
print(data)
# Out:
# {'location': {'name': 'London', 'region': 'City of London, Greater London', 'country': 'United Kingdom', 'lat': 51.5171, 'lon': -0.1062, 'tz_id': 'Europe/London', 'localtime_epoch': 1758136844, 'localtime': '2025-09-17 20:20'}, 'current': {'last_updated_epoch': 1758136500, 'last_updated': '2025-09-17 20:15', 'temp_c': 18.2, 'temp_f': 64.8, 'is_day': 0, 'condition': {'text': 'Overcast', 'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png', 'code': 1009}, 'wind_mph': 12.1, 'wind_kph': 19.4, 'wind_degree': 227, 'wind_dir': 'SW', 'pressure_mb': 1016.0, 'pressure_in': 30.0, 'precip_mm': 0.01, 'precip_in': 0.0, 'humidity': 88, 'cloud': 100, 'feelslike_c': 18.2, 'feelslike_f': 64.8, 'windchill_c': 17.5, 'windchill_f': 63.6, 'heatindex_c': 17.5, 'heatindex_f': 63.6, 'dewpoint_c': 15.6, 'dewpoint_f': 60.1, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 0.0, 'gust_mph': 17.4, 'gust_kph': 28.0, 'short_rad': 0, 'diff_rad': 0, 'dni': 0, 'gti': 0}, 'forecast': {'forecastday': [{'date': '2025-09-17', 'date_epoch': 1758067200, 'day': {'maxtemp_c': 18.3, 'maxtemp_f': 65.0, 'mintemp_c': 13.1, 'mintemp_f': 55.6, 'avgtemp_c': 16.1, 'avgtemp_f': 61.0, 'maxwind_mph': 15.9, 'maxwind_kph': 25.6, 'totalprecip_mm': 2.18, 'totalprecip_in': 0.09, 'totalsnow_cm': 0.0, 'avgvis_km': 9.0, 'avgvis_miles': 5.0, 'avghumidity': 85, 'daily_will_it_rain': 1, 'daily_chance_of_rain': 99, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Patchy rain nearby', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'uv': 0.2}, 'astro': {'sunrise': '06:39 AM', 'sunset': '07:10 PM', 'moonrise': '12:54 AM', 'moonset': '05:54 PM', 'moon_phase': 'Waning Crescent', 'moon_illumination': 23, 'is_moon_up': 0, 'is_sun_up': 0}, 'hour': [{'time_epoch': 1758063600, 'time': '2025-09-17 00:00', 'temp_c': 14.1, 'temp_f': 57.3, 'is_day': 0, 'condition': {'text': 'Partly Cloudy ', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 6.5, 'wind_kph': 10.4, 'wind_degree': 233, 'wind_dir': 'SW', 'pressure_mb': 1019.0, 'pressure_in': 30.09, 'precip_mm': 0.0, 'precip_in': 0.0, 'snow_cm': 0.0, 'humidity': 73, 'cloud': 55, 'feelslike_c': 13.4, 'feelslike_f': 56.2, 'windchill_c': 13.4, 'windchill_f': 56.2, 'heatindex_c': 14.1, 'heatindex_f': 57.3, 'dewpoint_c': 9.2, 'dewpoint_f': 48.6, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 9.1, 'gust_kph': 14.7, 'uv': 0, 'short_rad': 0, 'diff_rad': 0, 'dni': 0, 'gti': 0}, {'time_epoch': 1758067200, 'time': '2025-09-17 01:00', 'temp_c': 13.8, 'temp_f': 56.9, 'is_day': 0, 'condition': {'text': 'Overcast ', 'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png', 'code': 1009}, 'wind_mph': 7.2, 'wind_kph': 11.5, 'wind_degree': 226, 'wind_dir': 'SW', 'pressure_mb': 1019.0, 'pressure_in': 30.08, 'precip_mm': 0.0, 'precip_in': 0.0, 'snow_cm': 0.0, 'humidity': 75, 'cloud': 100, 'feelslike_c': 13.0, 'feelslike_f': 55.5, 'windchill_c': 13.0, 'windchill_f': 55.5, 'heatindex_c': 13.8, 'heatindex_f': 56.9, 'dewpoint_c': 9.6, 'dewpoint_f': 49.3, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 10.0, 'gust_kph': 16.1, 'uv': 0, 'short_rad': 0, 'diff_rad': 0, 'dni': 0, 'gti': 0}, {'time_epoch': 1758070800, 'time': '2025-09-17 02:00', 'temp_c': 13.6, 'temp_f': 56.4, 'is_day': 0, 'condition': {'text': 'Light drizzle', 'icon': '//cdn.weatherapi.com/weather/64x64/night/266.png', 'code': 1153}, 'wind_mph': 7.6, 'wind_kph': 12.2, 'wind_degree': 230, 'wind_dir': 'SW', 'pressure_mb': 1018.0, 'pressure_in': 30.07, 'precip_mm': 0.16, 'precip_in': 0.01, 'snow_cm': 0.0, 'humidity': 79, 'cloud': 91, 'feelslike_c': 12.6, 'feelslike_f': 54.7, 'windchill_c': 12.6, 'windchill_f': 54.7, 'heatindex_c': 13.6, 'heatindex_f': 56.4, 'dewpoint_c': 10.0, 'dewpoint_f': 50.0, 'will_it_rain': 1, 'chance_of_rain': 100, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km' ...

# %%
with req.urlopen(url) as session:
  response1 = session.read().decode()

response1
# Out:
# '{"location":{"name":"London","region":"City of London, Greater London","country":"United Kingdom","lat":51.5171,"lon":-0.1062,"tz_id":"Europe/London","localtime_epoch":1758136844,"localtime":"2025-09-17 20:20"},"current":{"last_updated_epoch":1758136500,"last_updated":"2025-09-17 20:15","temp_c":18.2,"temp_f":64.8,"is_day":0,"condition":{"text":"Overcast","icon":"//cdn.weatherapi.com/weather/64x64/night/122.png","code":1009},"wind_mph":12.1,"wind_kph":19.4,"wind_degree":227,"wind_dir":"SW","pressure_mb":1016.0,"pressure_in":30.0,"precip_mm":0.01,"precip_in":0.0,"humidity":88,"cloud":100,"feelslike_c":18.2,"feelslike_f":64.8,"windchill_c":17.5,"windchill_f":63.6,"heatindex_c":17.5,"heatindex_f":63.6,"dewpoint_c":15.6,"dewpoint_f":60.1,"vis_km":10.0,"vis_miles":6.0,"uv":0.0,"gust_mph":17.4,"gust_kph":28.0,"short_rad":0,"diff_rad":0,"dni":0,"gti":0},"forecast":{"forecastday":[{"date":"2025-09-17","date_epoch":1758067200,"day":{"maxtemp_c":18.3,"maxtemp_f":65.0,"mintemp_c":13.1,"mintemp_f":55.6,"avgtemp_c":16.1,"avgtemp_f":61.0,"maxwind_mph":15.9,"maxwind_kph":25.6,"totalprecip_mm":2.18,"totalprecip_in":0.09,"totalsnow_cm":0.0,"avgvis_km":9.0,"avgvis_miles":5.0,"avghumidity":85,"daily_will_it_rain":1,"daily_chance_of_rain":99,"daily_will_it_snow":0,"daily_chance_of_snow":0,"condition":{"text":"Patchy rain nearby","icon":"//cdn.weatherapi.com/weather/64x64/day/176.png","code":1063},"uv":0.2},"astro":{"sunrise":"06:39 AM","sunset":"07:10 PM","moonrise":"12:54 AM","moonset":"05:54 PM","moon_phase":"Waning Crescent","moon_illumination":23,"is_moon_up":0,"is_sun_up":0},"hour":[{"time_epoch":1758063600,"time":"2025-09-17 00:00","temp_c":14.1,"temp_f":57.3,"is_day":0,"condition":{"text":"Partly Cloudy ","icon":"//cdn.weatherapi.com/weather/64x64/night/116.png","code":1003},"wind_mph":6.5,"wind_kph":10.4,"wind_degree":233,"wind_dir":"SW","pressure_mb":1019.0,"pressure_in":30.09,"precip_mm":0.0,"precip_in":0.0,"snow_cm":0.0,"humidity":73,"cloud":55,"feelslike_c":13.4,"feelslike_f":56.2,"windchill_c":13.4,"windchill_f":56.2,"heatindex_c":14.1,"heatindex_f":57.3,"dewpoint_c":9.2,"dewpoint_f":48.6,"will_it_rain":0,"chance_of_rain":0,"will_it_snow":0,"chance_of_snow":0,"vis_km":10.0,"vis_miles":6.0,"gust_mph":9.1,"gust_kph":14.7,"uv":0,"short_rad":0,"diff_rad":0,"dni":0,"gti":0},{"time_epoch":1758067200,"time":"2025-09-17 01:00","temp_c":13.8,"temp_f":56.9,"is_day":0,"condition":{"text":"Overcast ","icon":"//cdn.weatherapi.com/weather/64x64/night/122.png","code":1009},"wind_mph":7.2,"wind_kph":11.5,"wind_degree":226,"wind_dir":"SW","pressure_mb":1019.0,"pressure_in":30.08,"precip_mm":0.0,"precip_in":0.0,"snow_cm":0.0,"humidity":75,"cloud":100,"feelslike_c":13.0,"feelslike_f":55.5,"windchill_c":13.0,"windchill_f":55.5,"heatindex_c":13.8,"heatindex_f":56.9,"dewpoint_c":9.6,"dewpoint_f":49.3,"will_it_rain":0,"chance_of_rain":0,"will_it_snow":0,"chance_of_snow":0,"vis_km":10.0,"vis_miles":6.0,"gust_mph":10.0,"gust_kph":16.1,"uv":0,"short_rad":0,"diff_rad":0,"dni":0,"gti":0},{"time_epoch":1758070800,"time":"2025-09-17 02:00","temp_c":13.6,"temp_f":56.4,"is_day":0,"condition":{"text":"Light drizzle","icon":"//cdn.weatherapi.com/weather/64x64/night/266.png","code":1153},"wind_mph":7.6,"wind_kph":12.2,"wind_degree":230,"wind_dir":"SW","pressure_mb":1018.0,"pressure_in":30.07,"precip_mm":0.16,"precip_in":0.01,"snow_cm":0.0,"humidity":79,"cloud":91,"feelslike_c":12.6,"feelslike_f":54.7,"windchill_c":12.6,"windchill_f":54.7,"heatindex_c":13.6,"heatindex_f":56.4,"dewpoint_c":10.0,"dewpoint_f":50.0,"will_it_rain":1,"chance_of_rain":100,"will_it_snow":0,"chance_of_snow":0,"vis_km":2.0,"vis_miles":1.0,"gust_mph":10.6,"gust_kph":17.0,"uv":0,"short_rad":0,"diff_rad":0,"dni":0,"gti":0},{"time_epoch":1758074400,"time":"2025-09-17 03:00","temp_c":13.1,"temp_f":55.6,"is_day":0,"condition":{"text":"Light rain","icon":"//cdn.weatherapi.com/weather/64x64/night/296.png","code":1183},"wind_mph":5.4,"wind_kph":8.6,"wind_degree":220,"wind_dir":"SW","pressure_mb":1019.0, ...

# %%
import json
#преобразуем в тип json
data = json.loads(response)
data
# Out:
# {'location': {'name': 'London',
#   'region': 'City of London, Greater London',
#   'country': 'United Kingdom',
#   'lat': 51.5171,
#   'lon': -0.1062,
#   'tz_id': 'Europe/London',
#   'localtime_epoch': 1758136844,
#   'localtime': '2025-09-17 20:20'},
#  'current': {'last_updated_epoch': 1758136500,
#   'last_updated': '2025-09-17 20:15',
#   'temp_c': 18.2,
#   'temp_f': 64.8,
#   'is_day': 0,
#   'condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#    'code': 1009},
#   'wind_mph': 12.1,
#   'wind_kph': 19.4,
#   'wind_degree': 227,
#   'wind_dir': 'SW',
#   'pressure_mb': 1016.0,
#   'pressure_in': 30.0,
#   'precip_mm': 0.01,
#   'precip_in': 0.0,
#   'humidity': 88,
#   'cloud': 100,
#   'feelslike_c': 18.2,
#   'feelslike_f': 64.8,
#   'windchill_c': 17.5,
#   'windchill_f': 63.6,
#   'heatindex_c': 17.5,
#   'heatindex_f': 63.6,
#   'dewpoint_c': 15.6,
#   'dewpoint_f': 60.1,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 0.0,
#   'gust_mph': 17.4,
#   'gust_kph': 28.0,
#   'short_rad': 0,
#   'diff_rad': 0,
#   'dni': 0,
#   'gti': 0},
#  'forecast': {'forecastday': [{'date': '2025-09-17',
#     'date_epoch': 1758067200,
#     'day': {'maxtemp_c': 18.3,
#      'maxtemp_f': 65.0,
#      'mintemp_c': 13.1,
#      'mintemp_f': 55.6,
#      'avgtemp_c': 16.1,
#      'avgtemp_f': 61.0,
#      'maxwind_mph': 15.9,
#      'maxwind_kph': 25.6,
#      'totalprecip_mm': 2.18,
#      'totalprecip_in': 0.09,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 9.0,
#      'avgvis_miles': 5.0,
#      'avghumidity': 85,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 99,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain nearby',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'uv': 0.2},
#     'astro': {'sunrise': '06:39 AM',
#      'sunset': '07:10 PM',
#      'moonrise': '12:54 AM',
#      'moonset': '05:54 PM',
#      'moon_phase': 'Waning Crescent',
#      'moon_illumination': 23,
#      'is_moon_up': 0,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1758063600,
#       'time': '2025-09-17 00:00',
#       'temp_c': 14.1,
#       'temp_f': 57.3,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 233,
#       'wind_dir': 'SW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 73,
#       'cloud': 55,
#       'feelslike_c': 13.4,
#       'feelslike_f': 56.2,
#       'windchill_c': 13.4,
#       'windchill_f': 56.2,
#       'heatindex_c': 14.1,
#       'heatindex_f': 57.3,
#       'dewpoint_c': 9.2,
#       'dewpoint_f': 48.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.1,
#       'gust_kph': 14.7,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758067200,
#       'time': '2025-09-17 01:00',
#       'temp_c': 13.8,
#       'temp_f': 56.9,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 226,
#       'wind_dir': 'SW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.08,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 75,
#       'cloud': 100,
#       'feelslike_c': 13.0,
#       'feelslike_f': 55.5,
#       'windchill_c': 13.0,
#       'windchill_f': 55.5,
#       'heatindex_c': 13.8,
#       'heatindex_f': 56.9,
#       'dewpoint_c': 9.6,
#       'dewpoint_f': 49.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.0,
#       'gust_kph': 16.1,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758070800,
#       'time': '2025-09-17 02:00',
#       'temp_c': 13.6,
#       'temp_f': 56.4,
#       'is_day': 0,
#       'condition': {'text': 'Light drizzle',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/266.png',
#        'code': 1153},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 230,
#       'wind_dir': 'SW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.07,
#       'precip_mm': 0.16,
#       'precip_in': 0.01,
#       'snow_cm': 0.0,
#       'humidity': 79,
#       'cloud': 91,
#       'feelslike_c': 12.6,
#       'feelslike_f': 54.7,
#       'windchill_c': 12.6,
#       'windchill_f': 54.7,
#       'heatindex_c': 13.6,
#       'heatindex_f': 56.4,
#       'dewpoint_c': 10.0,
#       'dewpoint_f': 50.0,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 2.0,
#       'vis_miles': 1.0,
#       'gust_mph': 10.6,
#       'gust_kph': 17.0,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758074400,
#       'time': '2025-09-17 03:00',
#       'temp_c': 13.1,
#       'temp_f': 55.6,
#       'is_day': 0,
#       'condition': {'text': 'Light rain',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/296.png',
#        'code': 1183},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 220,
#       'wind_dir': 'SW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.08,
#       'precip_mm': 0.93,
#       'precip_in': 0.04,
#       'snow_cm': 0.0,
#       'humidity': 89,
#       'cloud': 100,
#       'feelslike_c': 12.6,
#       'feelslike_f': 54.6,
#       'windchill_c': 12.6,
#       'windchill_f': 54.6,
#       'heatindex_c': 13.1,
#       'heatindex_f': 55.6,
#       'dewpoint_c': 11.4,
#       'dewpoint_f': 52.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 7.5,
#       'gust_kph': 12.1,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758078000,
#       'time': '2025-09-17 04:00',
#       'temp_c': 13.2,
#       'temp_f': 55.7,
#       'is_day': 0,
#       'condition': {'text': 'Light drizzle',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/266.png',
#        'code': 1153},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 193,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.44,
#       'precip_in': 0.02,
#       'snow_cm': 0.0,
#       'humidity': 92,
#       'cloud': 100,
#       'feelslike_c': 12.4,
#       'feelslike_f': 54.2,
#       'windchill_c': 12.4,
#       'windchill_f': 54.2,
#       'heatindex_c': 13.2,
#       'heatindex_f': 55.7,
#       'dewpoint_c': 11.9,
#       'dewpoint_f': 53.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 2.0,
#       'vis_miles': 1.0,
#       'gust_mph': 9.4,
#       'gust_kph': 15.1,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758081600,
#       'time': '2025-09-17 05:00',
#       'temp_c': 13.5,
#       'temp_f': 56.4,
#       'is_day': 0,
#       'condition': {'text': 'Light drizzle',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/266.png',
#        'code': 1153},
#       'wind_mph': 8.1,
#       'wind_kph': 13.0,
#       'wind_degree': 193,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.45,
#       'precip_in': 0.02,
#       'snow_cm': 0.0,
#       'humidity': 92,
#       'cloud': 100,
#       'feelslike_c': 12.5,
#       'feelslike_f': 54.5,
#       'windchill_c': 12.5,
#       'windchill_f': 54.5,
#       'heatindex_c': 13.6,
#       'heatindex_f': 56.4,
#       'dewpoint_c': 12.2,
#       'dewpoint_f': 54.0,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 2.0,
#       'vis_miles': 1.0,
#       'gust_mph': 12.0,
#       'gust_kph': 19.3,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758085200,
#       'time': '2025-09-17 06:00',
#       'temp_c': 13.9,
#       'temp_f': 57.0,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 194,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.08,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 91,
#       'cloud': 100,
#       'feelslike_c': 12.5,
#       'feelslike_f': 54.6,
#       'windchill_c': 12.5,
#       'windchill_f': 54.6,
#       'heatindex_c': 13.9,
#       'heatindex_f': 57.0,
#       'dewpoint_c': 12.5,
#       'dewpoint_f': 54.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.7,
#       'gust_kph': 25.3,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758088800,
#       'time': '2025-09-17 07:00',
#       'temp_c': 14.2,
#       'temp_f': 57.6,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 12.5,
#       'wind_kph': 20.2,
#       'wind_degree': 202,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 90,
#       'cloud': 100,
#       'feelslike_c': 12.7,
#       'feelslike_f': 54.9,
#       'windchill_c': 12.7,
#       'windchill_f': 54.9,
#       'heatindex_c': 14.2,
#       'heatindex_f': 57.6,
#       'dewpoint_c': 12.6,
#       'dewpoint_f': 54.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 55,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 19.1,
#       'gust_kph': 30.7,
#       'uv': 0.0,
#       'short_rad': 0.02,
#       'diff_rad': 0.01,
#       'dni': 0.0,
#       'gti': 0.01},
#      {'time_epoch': 1758092400,
#       'time': '2025-09-17 08:00',
#       'temp_c': 14.7,
#       'temp_f': 58.5,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 14.1,
#       'wind_kph': 22.7,
#       'wind_degree': 208,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 89,
#       'cloud': 100,
#       'feelslike_c': 13.2,
#       'feelslike_f': 55.7,
#       'windchill_c': 13.2,
#       'windchill_f': 55.7,
#       'heatindex_c': 14.7,
#       'heatindex_f': 58.5,
#       'dewpoint_c': 12.9,
#       'dewpoint_f': 55.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 21.6,
#       'gust_kph': 34.7,
#       'uv': 0.0,
#       'short_rad': 2.34,
#       'diff_rad': 1.82,
#       'dni': 12.25,
#       'gti': 1.94},
#      {'time_epoch': 1758096000,
#       'time': '2025-09-17 09:00',
#       'temp_c': 15.7,
#       'temp_f': 60.2,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 15.7,
#       'wind_kph': 25.2,
#       'wind_degree': 215,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 85,
#       'cloud': 100,
#       'feelslike_c': 15.7,
#       'feelslike_f': 60.2,
#       'windchill_c': 15.7,
#       'windchill_f': 60.2,
#       'heatindex_c': 15.7,
#       'heatindex_f': 60.2,
#       'dewpoint_c': 13.1,
#       'dewpoint_f': 55.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 23.6,
#       'gust_kph': 38.0,
#       'uv': 0.1,
#       'short_rad': 8.46,
#       'diff_rad': 5.89,
#       'dni': 12.67,
#       'gti': 4.75},
#      {'time_epoch': 1758099600,
#       'time': '2025-09-17 10:00',
#       'temp_c': 16.4,
#       'temp_f': 61.5,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 15.9,
#       'wind_kph': 25.6,
#       'wind_degree': 216,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 100,
#       'feelslike_c': 16.4,
#       'feelslike_f': 61.5,
#       'windchill_c': 16.4,
#       'windchill_f': 61.5,
#       'heatindex_c': 16.4,
#       'heatindex_f': 61.5,
#       'dewpoint_c': 13.6,
#       'dewpoint_f': 56.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 22.4,
#       'gust_kph': 36.1,
#       'uv': 0.4,
#       'short_rad': 32.62,
#       'diff_rad': 19.99,
#       'dni': 35.93,
#       'gti': 14.52},
#      {'time_epoch': 1758103200,
#       'time': '2025-09-17 11:00',
#       'temp_c': 17.1,
#       'temp_f': 62.7,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 15.7,
#       'wind_kph': 25.2,
#       'wind_degree': 218,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 100,
#       'feelslike_c': 17.1,
#       'feelslike_f': 62.7,
#       'windchill_c': 17.1,
#       'windchill_f': 62.7,
#       'heatindex_c': 17.1,
#       'heatindex_f': 62.7,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 20.9,
#       'gust_kph': 33.7,
#       'uv': 1.1,
#       'short_rad': 58.11,
#       'diff_rad': 34.88,
#       'dni': 48.62,
#       'gti': 24.28},
#      {'time_epoch': 1758106800,
#       'time': '2025-09-17 12:00',
#       'temp_c': 17.7,
#       'temp_f': 63.9,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 15.7,
#       'wind_kph': 25.2,
#       'wind_degree': 221,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 81,
#       'cloud': 100,
#       'feelslike_c': 17.7,
#       'feelslike_f': 63.9,
#       'windchill_c': 17.7,
#       'windchill_f': 63.9,
#       'heatindex_c': 17.7,
#       'heatindex_f': 63.9,
#       'dewpoint_c': 14.5,
#       'dewpoint_f': 58.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 20.9,
#       'gust_kph': 33.7,
#       'uv': 0.5,
#       'short_rad': 86.26,
#       'diff_rad': 51.05,
#       'dni': 61.39,
#       'gti': 34.68},
#      {'time_epoch': 1758110400,
#       'time': '2025-09-17 13:00',
#       'temp_c': 17.9,
#       'temp_f': 64.2,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 15.0,
#       'wind_kph': 24.1,
#       'wind_degree': 224,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 81,
#       'cloud': 100,
#       'feelslike_c': 17.9,
#       'feelslike_f': 64.1,
#       'windchill_c': 17.9,
#       'windchill_f': 64.1,
#       'heatindex_c': 17.9,
#       'heatindex_f': 64.1,
#       'dewpoint_c': 14.6,
#       'dewpoint_f': 58.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 20.6,
#       'gust_kph': 33.2,
#       'uv': 0.6,
#       'short_rad': 102.51,
#       'diff_rad': 60.28,
#       'dni': 66.81,
#       'gti': 40.46},
#      {'time_epoch': 1758114000,
#       'time': '2025-09-17 14:00',
#       'temp_c': 17.9,
#       'temp_f': 64.2,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 14.3,
#       'wind_kph': 23.0,
#       'wind_degree': 227,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.07,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 100,
#       'feelslike_c': 17.9,
#       'feelslike_f': 64.2,
#       'windchill_c': 17.9,
#       'windchill_f': 64.2,
#       'heatindex_c': 17.9,
#       'heatindex_f': 64.2,
#       'dewpoint_c': 14.9,
#       'dewpoint_f': 58.8,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 20.0,
#       'gust_kph': 32.1,
#       'uv': 0.7,
#       'short_rad': 136.22,
#       'diff_rad': 83.36,
#       'dni': 81.39,
#       'gti': 57.23},
#      {'time_epoch': 1758117600,
#       'time': '2025-09-17 15:00',
#       'temp_c': 18.2,
#       'temp_f': 64.7,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 13.4,
#       'wind_kph': 21.6,
#       'wind_degree': 228,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 82,
#       'cloud': 100,
#       'feelslike_c': 18.2,
#       'feelslike_f': 64.7,
#       'windchill_c': 18.2,
#       'windchill_f': 64.7,
#       'heatindex_c': 18.2,
#       'heatindex_f': 64.7,
#       'dewpoint_c': 15.1,
#       'dewpoint_f': 59.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.6,
#       'gust_kph': 30.0,
#       'uv': 0.4,
#       'short_rad': 111.72,
#       'diff_rad': 68.98,
#       'dni': 68.46,
#       'gti': 47.7},
#      {'time_epoch': 1758121200,
#       'time': '2025-09-17 16:00',
#       'temp_c': 18.3,
#       'temp_f': 65.0,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 13.2,
#       'wind_kph': 21.2,
#       'wind_degree': 226,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 82,
#       'cloud': 100,
#       'feelslike_c': 18.3,
#       'feelslike_f': 65.0,
#       'windchill_c': 18.3,
#       'windchill_f': 65.0,
#       'heatindex_c': 18.3,
#       'heatindex_f': 65.0,
#       'dewpoint_c': 15.3,
#       'dewpoint_f': 59.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.3,
#       'gust_kph': 29.5,
#       'uv': 0.2,
#       'short_rad': 103.32,
#       'diff_rad': 63.33,
#       'dni': 71.58,
#       'gti': 43.91},
#      {'time_epoch': 1758124800,
#       'time': '2025-09-17 17:00',
#       'temp_c': 18.0,
#       'temp_f': 64.4,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 13.0,
#       'wind_kph': 20.9,
#       'wind_degree': 226,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 84,
#       'cloud': 100,
#       'feelslike_c': 18.0,
#       'feelslike_f': 64.4,
#       'windchill_c': 18.0,
#       'windchill_f': 64.4,
#       'heatindex_c': 18.0,
#       'heatindex_f': 64.4,
#       'dewpoint_c': 15.3,
#       'dewpoint_f': 59.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.4,
#       'gust_kph': 29.6,
#       'uv': 0.2,
#       'short_rad': 96.26,
#       'diff_rad': 58.66,
#       'dni': 82.33,
#       'gti': 41.17},
#      {'time_epoch': 1758128400,
#       'time': '2025-09-17 18:00',
#       'temp_c': 17.6,
#       'temp_f': 63.7,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 12.5,
#       'wind_kph': 20.2,
#       'wind_degree': 228,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 86,
#       'cloud': 100,
#       'feelslike_c': 17.6,
#       'feelslike_f': 63.7,
#       'windchill_c': 17.6,
#       'windchill_f': 63.7,
#       'heatindex_c': 17.6,
#       'heatindex_f': 63.7,
#       'dewpoint_c': 15.3,
#       'dewpoint_f': 59.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.2,
#       'gust_kph': 29.3,
#       'uv': 0.1,
#       'short_rad': 82.1,
#       'diff_rad': 50.13,
#       'dni': 98.23,
#       'gti': 36.41},
#      {'time_epoch': 1758132000,
#       'time': '2025-09-17 19:00',
#       'temp_c': 17.6,
#       'temp_f': 63.7,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 12.1,
#       'wind_kph': 19.4,
#       'wind_degree': 229,
#       'wind_dir': 'SW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 87,
#       'cloud': 100,
#       'feelslike_c': 17.6,
#       'feelslike_f': 63.7,
#       'windchill_c': 17.6,
#       'windchill_f': 63.7,
#       'heatindex_c': 17.6,
#       'heatindex_f': 63.7,
#       'dewpoint_c': 15.5,
#       'dewpoint_f': 59.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.5,
#       'gust_kph': 28.2,
#       'uv': 0.0,
#       'short_rad': 69.22,
#       'diff_rad': 42.3,
#       'dni': 154.84,
#       'gti': 33.8},
#      {'time_epoch': 1758135600,
#       'time': '2025-09-17 20:00',
#       'temp_c': 18.2,
#       'temp_f': 64.8,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 12.1,
#       'wind_kph': 19.4,
#       'wind_degree': 227,
#       'wind_dir': 'SW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 88,
#       'cloud': 100,
#       'feelslike_c': 17.5,
#       'feelslike_f': 63.6,
#       'windchill_c': 17.5,
#       'windchill_f': 63.6,
#       'heatindex_c': 17.5,
#       'heatindex_f': 63.6,
#       'dewpoint_c': 15.6,
#       'dewpoint_f': 60.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 82,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.4,
#       'gust_kph': 28.0,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758139200,
#       'time': '2025-09-17 21:00',
#       'temp_c': 17.5,
#       'temp_f': 63.5,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 11.4,
#       'wind_kph': 18.4,
#       'wind_degree': 234,
#       'wind_dir': 'SW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 89,
#       'cloud': 100,
#       'feelslike_c': 17.5,
#       'feelslike_f': 63.5,
#       'windchill_c': 17.5,
#       'windchill_f': 63.5,
#       'heatindex_c': 17.5,
#       'heatindex_f': 63.5,
#       'dewpoint_c': 15.7,
#       'dewpoint_f': 60.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.4,
#       'gust_kph': 26.4,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758142800,
#       'time': '2025-09-17 22:00',
#       'temp_c': 17.4,
#       'temp_f': 63.3,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 230,
#       'wind_dir': 'SW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 90,
#       'cloud': 99,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.3,
#       'windchill_c': 17.4,
#       'windchill_f': 63.3,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.3,
#       'dewpoint_c': 15.7,
#       'dewpoint_f': 60.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.3,
#       'gust_kph': 23.0,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758146400,
#       'time': '2025-09-17 23:00',
#       'temp_c': 17.4,
#       'temp_f': 63.3,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 229,
#       'wind_dir': 'SW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 90,
#       'cloud': 100,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.3,
#       'windchill_c': 17.4,
#       'windchill_f': 63.3,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.3,
#       'dewpoint_c': 15.8,
#       'dewpoint_f': 60.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.1,
#       'gust_kph': 24.3,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0}]},
#    {'date': '2025-09-18',
#     'date_epoch': 1758153600,
#     'day': {'maxtemp_c': 23.2,
#      'maxtemp_f': 73.8,
#      'mintemp_c': 17.2,
#      'mintemp_f': 62.9,
#      'avgtemp_c': 19.3,
#      'avgtemp_f': 66.7,
#      'maxwind_mph': 15.2,
#      'maxwind_kph': 24.5,
#      'totalprecip_mm': 0.03,
#      'totalprecip_in': 0.0,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 77,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': 0,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Partly Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#       'code': 1003},
#      'uv': 1.0},
#     'astro': {'sunrise': '06:40 AM',
#      'sunset': '07:08 PM',
#      'moonrise': '02:17 AM',
#      'moonset': '06:12 PM',
#      'moon_phase': 'Waning Crescent',
#      'moon_illumination': 15,
#      'is_moon_up': 0,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1758150000,
#       'time': '2025-09-18 00:00',
#       'temp_c': 17.4,
#       'temp_f': 63.3,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 232,
#       'wind_dir': 'SW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 90,
#       'cloud': 100,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.3,
#       'windchill_c': 17.4,
#       'windchill_f': 63.3,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.3,
#       'dewpoint_c': 15.7,
#       'dewpoint_f': 60.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.2,
#       'gust_kph': 24.4,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758153600,
#       'time': '2025-09-18 01:00',
#       'temp_c': 17.4,
#       'temp_f': 63.3,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 9.4,
#       'wind_kph': 15.1,
#       'wind_degree': 229,
#       'wind_dir': 'SW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 91,
#       'cloud': 100,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.3,
#       'windchill_c': 17.4,
#       'windchill_f': 63.3,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.3,
#       'dewpoint_c': 15.9,
#       'dewpoint_f': 60.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.7,
#       'gust_kph': 22.0,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758157200,
#       'time': '2025-09-18 02:00',
#       'temp_c': 17.4,
#       'temp_f': 63.4,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 225,
#       'wind_dir': 'SW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 92,
#       'cloud': 100,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.4,
#       'windchill_c': 17.4,
#       'windchill_f': 63.4,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.4,
#       'dewpoint_c': 16.1,
#       'dewpoint_f': 61.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.5,
#       'gust_kph': 23.4,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758160800,
#       'time': '2025-09-18 03:00',
#       'temp_c': 17.6,
#       'temp_f': 63.7,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 226,
#       'wind_dir': 'SW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 90,
#       'cloud': 100,
#       'feelslike_c': 17.6,
#       'feelslike_f': 63.7,
#       'windchill_c': 17.6,
#       'windchill_f': 63.7,
#       'heatindex_c': 17.6,
#       'heatindex_f': 63.7,
#       'dewpoint_c': 16.1,
#       'dewpoint_f': 60.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 61,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.7,
#       'gust_kph': 25.3,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758164400,
#       'time': '2025-09-18 04:00',
#       'temp_c': 17.5,
#       'temp_f': 63.6,
#       'is_day': 0,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 223,
#       'wind_dir': 'SW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 90,
#       'cloud': 100,
#       'feelslike_c': 17.5,
#       'feelslike_f': 63.6,
#       'windchill_c': 17.5,
#       'windchill_f': 63.6,
#       'heatindex_c': 17.5,
#       'heatindex_f': 63.6,
#       'dewpoint_c': 15.9,
#       'dewpoint_f': 60.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.4,
#       'gust_kph': 24.8,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758168000,
#       'time': '2025-09-18 05:00',
#       'temp_c': 17.5,
#       'temp_f': 63.5,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 11.2,
#       'wind_kph': 18.0,
#       'wind_degree': 225,
#       'wind_dir': 'SW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 90,
#       'cloud': 100,
#       'feelslike_c': 17.5,
#       'feelslike_f': 63.5,
#       'windchill_c': 17.5,
#       'windchill_f': 63.5,
#       'heatindex_c': 17.5,
#       'heatindex_f': 63.5,
#       'dewpoint_c': 15.8,
#       'dewpoint_f': 60.4,
#       'will_it_rain': 1,
#       'chance_of_rain': 71,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.4,
#       'gust_kph': 26.4,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758171600,
#       'time': '2025-09-18 06:00',
#       'temp_c': 17.4,
#       'temp_f': 63.3,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 219,
#       'wind_dir': 'SW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 89,
#       'cloud': 95,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.2,
#       'windchill_c': 17.4,
#       'windchill_f': 63.2,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.2,
#       'dewpoint_c': 15.5,
#       'dewpoint_f': 59.8,
#       'will_it_rain': 1,
#       'chance_of_rain': 79,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.9,
#       'gust_kph': 24.0,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758175200,
#       'time': '2025-09-18 07:00',
#       'temp_c': 17.4,
#       'temp_f': 63.4,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 11.0,
#       'wind_kph': 17.6,
#       'wind_degree': 219,
#       'wind_dir': 'SW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 88,
#       'cloud': 100,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.4,
#       'windchill_c': 17.4,
#       'windchill_f': 63.4,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.4,
#       'dewpoint_c': 15.4,
#       'dewpoint_f': 59.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.4,
#       'gust_kph': 24.8,
#       'uv': 0.0,
#       'short_rad': 0.1,
#       'diff_rad': 0.06,
#       'dni': 0.0,
#       'gti': 0.05},
#      {'time_epoch': 1758178800,
#       'time': '2025-09-18 08:00',
#       'temp_c': 17.7,
#       'temp_f': 63.9,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 11.4,
#       'wind_kph': 18.4,
#       'wind_degree': 222,
#       'wind_dir': 'SW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.07,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 86,
#       'cloud': 99,
#       'feelslike_c': 17.8,
#       'feelslike_f': 64.0,
#       'windchill_c': 17.8,
#       'windchill_f': 64.0,
#       'heatindex_c': 17.8,
#       'heatindex_f': 64.0,
#       'dewpoint_c': 15.3,
#       'dewpoint_f': 59.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.8,
#       'gust_kph': 25.4,
#       'uv': 0.2,
#       'short_rad': 13.8,
#       'diff_rad': 8.36,
#       'dni': 141.42,
#       'gti': 10.73},
#      {'time_epoch': 1758182400,
#       'time': '2025-09-18 09:00',
#       'temp_c': 18.9,
#       'temp_f': 66.0,
#       'is_day': 1,
#       'condition': {'text': 'Overcast ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 13.2,
#       'wind_kph': 21.2,
#       'wind_degree': 225,
#       'wind_dir': 'SW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 76,
#       'cloud': 100,
#       'feelslike_c': 18.9,
#       'feelslike_f': 66.0,
#       'windchill_c': 18.9,
#       'windchill_f': 66.0,
#       'heatindex_c': 18.9,
#       'heatindex_f': 66.0,
#       'dewpoint_c': 14.6,
#       'dewpoint_f': 58.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.5,
#       'gust_kph': 26.6,
#       'uv': 0.8,
#       'short_rad': 27.3,
#       'diff_rad': 16.7,
#       'dni': 53.36,
#       'gti': 12.75},
#      {'time_epoch': 1758186000,
#       'time': '2025-09-18 10:00',
#       'temp_c': 19.2,
#       'temp_f': 66.6,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 12.5,
#       'wind_kph': 20.2,
#       'wind_degree': 220,
#       'wind_dir': 'SW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 73,
#       'cloud': 79,
#       'feelslike_c': 19.2,
#       'feelslike_f': 66.6,
#       'windchill_c': 19.2,
#       'windchill_f': 66.6,
#       'heatindex_c': 19.2,
#       'heatindex_f': 66.6,
#       'dewpoint_c': 14.4,
#       'dewpoint_f': 57.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.2,
#       'gust_kph': 26.0,
#       'uv': 1.6,
#       'short_rad': 94.02,
#       'diff_rad': 48.89,
#       'dni': 130.05,
#       'gti': 31.72},
#      {'time_epoch': 1758189600,
#       'time': '2025-09-18 11:00',
#       'temp_c': 21.2,
#       'temp_f': 70.2,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 14.3,
#       'wind_kph': 23.0,
#       'wind_degree': 225,
#       'wind_dir': 'SW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.08,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 64,
#       'cloud': 67,
#       'feelslike_c': 21.2,
#       'feelslike_f': 70.1,
#       'windchill_c': 21.2,
#       'windchill_f': 70.1,
#       'heatindex_c': 24.5,
#       'heatindex_f': 76.0,
#       'dewpoint_c': 14.1,
#       'dewpoint_f': 57.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.5,
#       'gust_kph': 26.6,
#       'uv': 2.9,
#       'short_rad': 108.5,
#       'diff_rad': 58.62,
#       'dni': 105.38,
#       'gti': 37.48},
#      {'time_epoch': 1758193200,
#       'time': '2025-09-18 12:00',
#       'temp_c': 22.4,
#       'temp_f': 72.3,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 14.8,
#       'wind_kph': 23.8,
#       'wind_degree': 225,
#       'wind_dir': 'SW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.08,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 60,
#       'cloud': 85,
#       'feelslike_c': 24.7,
#       'feelslike_f': 76.4,
#       'windchill_c': 22.4,
#       'windchill_f': 72.3,
#       'heatindex_c': 24.7,
#       'heatindex_f': 76.4,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.0,
#       'gust_kph': 27.3,
#       'uv': 4.0,
#       'short_rad': 173.17,
#       'diff_rad': 86.47,
#       'dni': 152.41,
#       'gti': 50.86},
#      {'time_epoch': 1758196800,
#       'time': '2025-09-18 13:00',
#       'temp_c': 23.0,
#       'temp_f': 73.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 15.0,
#       'wind_kph': 24.1,
#       'wind_degree': 225,
#       'wind_dir': 'SW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.07,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 56,
#       'cloud': 52,
#       'feelslike_c': 24.9,
#       'feelslike_f': 76.8,
#       'windchill_c': 23.0,
#       'windchill_f': 73.5,
#       'heatindex_c': 24.9,
#       'heatindex_f': 76.8,
#       'dewpoint_c': 13.9,
#       'dewpoint_f': 57.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.2,
#       'gust_kph': 27.8,
#       'uv': 4.4,
#       'short_rad': 237.84,
#       'diff_rad': 104.2,
#       'dni': 213.09,
#       'gti': 52.82},
#      {'time_epoch': 1758200400,
#       'time': '2025-09-18 14:00',
#       'temp_c': 23.2,
#       'temp_f': 73.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 15.2,
#       'wind_kph': 24.5,
#       'wind_degree': 228,
#       'wind_dir': 'SW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.07,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 55,
#       'cloud': 38,
#       'feelslike_c': 25.0,
#       'feelslike_f': 76.9,
#       'windchill_c': 23.2,
#       'windchill_f': 73.8,
#       'heatindex_c': 25.0,
#       'heatindex_f': 76.9,
#       'dewpoint_c': 13.9,
#       'dewpoint_f': 56.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.5,
#       'gust_kph': 28.2,
#       'uv': 4.1,
#       'short_rad': 592.96,
#       'diff_rad': 145.81,
#       'dni': 694.05,
#       'gti': 3.61},
#      {'time_epoch': 1758204000,
#       'time': '2025-09-18 15:00',
#       'temp_c': 23.2,
#       'temp_f': 73.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 13.9,
#       'wind_kph': 22.3,
#       'wind_degree': 228,
#       'wind_dir': 'SW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 55,
#       'cloud': 25,
#       'feelslike_c': 25.0,
#       'feelslike_f': 76.9,
#       'windchill_c': 23.2,
#       'windchill_f': 73.8,
#       'heatindex_c': 25.0,
#       'heatindex_f': 76.9,
#       'dewpoint_c': 13.8,
#       'dewpoint_f': 56.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.0,
#       'gust_kph': 25.7,
#       'uv': 3.1,
#       'short_rad': 575.96,
#       'diff_rad': 123.99,
#       'dni': 730.19,
#       'gti': 0.0},
#      {'time_epoch': 1758207600,
#       'time': '2025-09-18 16:00',
#       'temp_c': 22.9,
#       'temp_f': 73.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 12.3,
#       'wind_kph': 19.8,
#       'wind_degree': 225,
#       'wind_dir': 'SW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.07,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 57,
#       'cloud': 13,
#       'feelslike_c': 24.8,
#       'feelslike_f': 76.7,
#       'windchill_c': 22.9,
#       'windchill_f': 73.2,
#       'heatindex_c': 24.8,
#       'heatindex_f': 76.7,
#       'dewpoint_c': 13.9,
#       'dewpoint_f': 57.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.9,
#       'gust_kph': 23.9,
#       'uv': 2.0,
#       'short_rad': 538.72,
#       'diff_rad': 113.38,
#       'dni': 769.17,
#       'gti': 0.0},
#      {'time_epoch': 1758211200,
#       'time': '2025-09-18 17:00',
#       'temp_c': 21.7,
#       'temp_f': 71.0,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 220,
#       'wind_dir': 'SW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.08,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 63,
#       'cloud': 30,
#       'feelslike_c': 21.7,
#       'feelslike_f': 71.0,
#       'windchill_c': 21.7,
#       'windchill_f': 71.0,
#       'heatindex_c': 24.5,
#       'heatindex_f': 76.1,
#       'dewpoint_c': 14.4,
#       'dewpoint_f': 57.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.7,
#       'gust_kph': 25.3,
#       'uv': 0.9,
#       'short_rad': 488.06,
#       'diff_rad': 104.1,
#       'dni': 851.72,
#       'gti': 0.0},
#      {'time_epoch': 1758214800,
#       'time': '2025-09-18 18:00',
#       'temp_c': 19.9,
#       'temp_f': 67.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 11.2,
#       'wind_kph': 18.0,
#       'wind_degree': 219,
#       'wind_dir': 'SW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 74,
#       'cloud': 38,
#       'feelslike_c': 19.9,
#       'feelslike_f': 67.8,
#       'windchill_c': 19.9,
#       'windchill_f': 67.8,
#       'heatindex_c': 19.9,
#       'heatindex_f': 67.8,
#       'dewpoint_c': 15.0,
#       'dewpoint_f': 59.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.9,
#       'gust_kph': 25.7,
#       'uv': 0.3,
#       'short_rad': 427.97,
#       'diff_rad': 94.33,
#       'dni': 1044.71,
#       'gti': 7.91},
#      {'time_epoch': 1758218400,
#       'time': '2025-09-18 19:00',
#       'temp_c': 18.8,
#       'temp_f': 65.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 215,
#       'wind_dir': 'SW',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.11,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 80,
#       'cloud': 21,
#       'feelslike_c': 18.8,
#       'feelslike_f': 65.9,
#       'windchill_c': 18.8,
#       'windchill_f': 65.9,
#       'heatindex_c': 18.8,
#       'heatindex_f': 65.9,
#       'dewpoint_c': 15.2,
#       'dewpoint_f': 59.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.9,
#       'gust_kph': 24.0,
#       'uv': 0.0,
#       'short_rad': 364.34,
#       'diff_rad': 82.09,
#       'dni': 1683.95,
#       'gti': 35.73},
#      {'time_epoch': 1758222000,
#       'time': '2025-09-18 20:00',
#       'temp_c': 18.3,
#       'temp_f': 65.0,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 9.6,
#       'wind_kph': 15.5,
#       'wind_degree': 217,
#       'wind_dir': 'SW',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.12,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 82,
#       'cloud': 32,
#       'feelslike_c': 18.3,
#       'feelslike_f': 65.0,
#       'windchill_c': 18.3,
#       'windchill_f': 65.0,
#       'heatindex_c': 18.3,
#       'heatindex_f': 65.0,
#       'dewpoint_c': 15.1,
#       'dewpoint_f': 59.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.8,
#       'gust_kph': 22.3,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758225600,
#       'time': '2025-09-18 21:00',
#       'temp_c': 17.8,
#       'temp_f': 64.1,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 9.4,
#       'wind_kph': 15.1,
#       'wind_degree': 220,
#       'wind_dir': 'SW',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.12,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 51,
#       'feelslike_c': 17.8,
#       'feelslike_f': 64.1,
#       'windchill_c': 17.8,
#       'windchill_f': 64.1,
#       'heatindex_c': 17.8,
#       'heatindex_f': 64.1,
#       'dewpoint_c': 14.8,
#       'dewpoint_f': 58.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.9,
#       'gust_kph': 22.4,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758229200,
#       'time': '2025-09-18 22:00',
#       'temp_c': 17.5,
#       'temp_f': 63.4,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 220,
#       'wind_dir': 'SW',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.13,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 84,
#       'cloud': 60,
#       'feelslike_c': 17.5,
#       'feelslike_f': 63.4,
#       'windchill_c': 17.5,
#       'windchill_f': 63.4,
#       'heatindex_c': 17.5,
#       'heatindex_f': 63.4,
#       'dewpoint_c': 14.7,
#       'dewpoint_f': 58.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.1,
#       'gust_kph': 21.1,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0},
#      {'time_epoch': 1758232800,
#       'time': '2025-09-18 23:00',
#       'temp_c': 17.2,
#       'temp_f': 62.9,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 8.3,
#       'wind_kph': 13.3,
#       'wind_degree': 217,
#       'wind_dir': 'SW',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.12,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 85,
#       'cloud': 26,
#       'feelslike_c': 17.2,
#       'feelslike_f': 62.9,
#       'windchill_c': 17.2,
#       'windchill_f': 62.9,
#       'heatindex_c': 17.2,
#       'heatindex_f': 62.9,
#       'dewpoint_c': 14.6,
#       'dewpoint_f': 58.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.8,
#       'gust_kph': 20.6,
#       'uv': 0,
#       'short_rad': 0,
#       'diff_rad': 0,
#       'dni': 0,
#       'gti': 0}]}]}}

# %%
len(data['forecast']['forecastday'])
# Out:
# 2

# %%
#получаем датафрейм
import pandas as pd

d = []

for i in range(days):
  d_outer = data['forecast']['forecastday'][i]
  d = d + d_outer['hour']
df = pd.DataFrame(d)
df.head(10)
# Out:
#    time_epoch              time  temp_c  temp_f  is_day  \
# 0  1758063600  2025-09-17 00:00    14.1    57.3       0
# 1  1758067200  2025-09-17 01:00    13.8    56.9       0
# 2  1758070800  2025-09-17 02:00    13.6    56.4       0
# 3  1758074400  2025-09-17 03:00    13.1    55.6       0
# 4  1758078000  2025-09-17 04:00    13.2    55.7       0
# 5  1758081600  2025-09-17 05:00    13.5    56.4       0
# 6  1758085200  2025-09-17 06:00    13.9    57.0       0
# 7  1758088800  2025-09-17 07:00    14.2    57.6       1
# 8  1758092400  2025-09-17 08:00    14.7    58.5       1
# 9  1758096000  2025-09-17 09:00    15.7    60.2       1
#
#                                            condition  wind_mph  wind_kph  \
# 0  {'text': 'Partly Cloudy ', 'icon': '//cdn.weat...       6.5      10.4
# 1  {'text': 'Overcast ', 'icon': '//cdn.weatherap...       7.2      11.5
# 2  {'text': 'Light drizzle', 'icon': '//cdn.weath...       7.6      12.2
# 3  {'text': 'Light rain', 'icon': '//cdn.weathera...       5.4       8.6
# 4  {'text': 'Light drizzle', 'icon': '//cdn.weath...       6.5      10.4
# 5  {'text': 'Light drizzle', 'icon': '//cdn.weath...       8.1      13.0
# 6  {'text': 'Patchy rain nearby', 'icon': '//cdn....      10.5      16.9
# 7  {'text': 'Patchy rain nearby', 'icon': '//cdn....      12.5      20.2
# 8  {'text': 'Overcast ', 'icon': '//cdn.weatherap...      14.1      22.7
# 9  {'text': 'Overcast ', 'icon': '//cdn.weatherap...      15.7      25.2
#
#    wind_degree wind_dir  ...  chance_of_snow  vis_km  vis_miles  gust_mph  \
# 0          233       SW  ...               0    10.0        6.0       9.1
# 1          226       SW  ...               0    10.0        6.0      10.0
# 2          230       SW  ...               0     2.0        1.0      10.6
# 3          220       SW  ...               0     9.0        5.0       7.5
# 4          193      SSW  ...               0     2.0        1.0       9.4
# 5          193      SSW  ...               0     2.0        1.0      12.0
# 6          194      SSW  ...               0    10.0        6.0      15.7
# 7          202      SSW  ...               0    10.0        6.0      19.1
# 8          208      SSW  ...               0    10.0        6.0      21.6
# 9          215       SW  ...               0    10.0        6.0      23.6
#
#    gust_kph   uv  short_rad  diff_rad    dni   gti
# 0      14.7  0.0       0.00      0.00   0.00  0.00
# 1      16.1  0.0       0.00      0.00   0.00  0.00
# 2      17.0  0.0       0.00      0.00   0.00  0.00
# 3      12.1  0.0       0.00      0.00   0.00  0.00
# 4      15.1  0.0       0.00      0.00   0.00  0.00
# 5      19.3  0.0       0.00      0.00   0.00  0.00
# 6      25.3  0.0       0.00      0.00   0.00  0.00
# 7      30.7  0.0       0.02      0.01   0.00  0.01
# 8      34.7  0.0       2.34      1.82  12.25  1.94
# 9      38.0  0.1       8.46      5.89  12.67  4.75
#
# [10 rows x 38 columns]

# %% [markdown]
# ### Задача 2
#
# Сохраните данные погоды, полученные в предыдущей задаче, в файл `weather.json`. При сохранении используйте четыре пробела для форматирования.

# %%
#Запись в файл JSON
with open('file.json', 'w') as fileLondon:
    json.dump(data, fileLondon, indent=4)

# %% [markdown]
# ### Задача 3
#
# Из содержимого файла `weather.json` получите **почасовой** прогноз погоды, загрузите его в DataFrame и выведите первые пять строк DataFrame на экран.

# %%
#Чтение из JSON в pandas DataFrame
df = pd.read_json('file.json')
df.head(10)
# Out:
#                                           location           current forecast
# name                                        London               NaN      NaN
# region              City of London, Greater London               NaN      NaN
# country                             United Kingdom               NaN      NaN
# lat                                        51.5171               NaN      NaN
# lon                                        -0.1062               NaN      NaN
# tz_id                                Europe/London               NaN      NaN
# localtime_epoch                         1758136844               NaN      NaN
# localtime                         2025-09-17 20:20               NaN      NaN
# last_updated_epoch                             NaN        1758136500      NaN
# last_updated                                   NaN  2025-09-17 20:15      NaN

# %% [markdown]
# ### Задача 4
#
# Сохраните DataFrame из предыдущей задачи в файл `result.csv`. В качестве названия столбца-индекса используйте `index`.

# %%
#сохраняем в формат csv
df.to_csv('result.csv', sep = ',', index_label = 'index')

# %% [markdown]
# ### Задача 5
#
# Загрузите содержимое SQL-таблицы `ratings` в DataFrame. Выведите первые пять строк DataFrame на экран. Для подключения к БД используйте строку подключения, указанную в следующей ячейке.

# %%
import sqlalchemy
import psycopg2
connection = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5432/db_ds_students'

connection
# Out:
# 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5432/db_ds_students'

# %%
engine = sqlalchemy.create_engine(connection)
connect = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3298, in Engine.raw_connection(self)
#    3277 """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279 The returned object is a proxied version of the DBAPI
#    (...)
#    3296
#    3297 """
# -> 3298 return self.pool.connect()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
#     447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1263 if not fairy:
# -> 1264     fairy = _ConnectionRecord.checkout(pool)
#    1266     if threadconns is not None:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     176 try:
# --> 177     return self._create_connection()
#     178 except:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:901, in _ConnectionRecord.__connect(self)
#     900 except BaseException as e:
# --> 901     with util.safe_reraise():
#     902         pool.logger.debug("Error on connect(): %s", e)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:897, in _ConnectionRecord.__connect(self)
#     896 self.starttime = time.time()
# --> 897 self.dbapi_connection = connection = pool._invoke_creator(self)
#     898 pool.logger.debug("Created new connection %r", connection)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py:646, in create_engine.<locals>.connect(connection_record)
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:622, in DefaultDialect.connect(self, *cargs, **cparams)
#     620 def connect(self, *cargs, **cparams):
#     621     # inherits the docstring from interfaces.Dialect.connect
# --> 622     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#
# OperationalError: connection to server at "dsstudents.skillbox.ru" (91.236.196.30), port 5432 failed: FATAL:  no pg_hba.conf entry for host "172.22.7.3", user "readonly", database "db_ds_students", no encryption
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 2
#       1 engine = sqlalchemy.create_engine(connection)
# ----> 2 connect = engine.connect()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3274, in Engine.connect(self)
#    3251 def connect(self) -> Connection:
#    3252     """Return a new :class:`_engine.Connection` object.
#    3253
#    3254     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3271
#    3272     """
# -> 3274     return self._connection_cls(self)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:148, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
# --> 148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#     151         raise
#     152 else:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2439, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2437 elif should_wrap:
#    2438     assert sqlalchemy_exception is not None
# -> 2439     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2440 else:
#    2441     assert exc_info[1] is not None
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 if connection is None:
#     145     try:
# --> 146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
#     148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3298, in Engine.raw_connection(self)
#    3276 def raw_connection(self) -> PoolProxiedConnection:
#    3277     """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279     The returned object is a proxied version of the DBAPI
#    (...)
#    3296
#    3297     """
# -> 3298     return self.pool.connect()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1256 @classmethod
#    1257 def _checkout(
#    1258     cls,
#    (...)
#    1261     fairy: Optional[_ConnectionFairy] = None,
#    1262 ) -> _ConnectionFairy:
#    1263     if not fairy:
# -> 1264         fairy = _ConnectionRecord.checkout(pool)
#    1266         if threadconns is not None:
#    1267             threadconns.current = weakref.ref(fairy)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     711     rec = cast(_ConnectionRecord, pool._do_get())
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#     716     dbapi_connection = rec.get_connection()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     673 self.__pool = pool
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:901, in _ConnectionRecord.__connect(self)
#     899     self.fresh = True
#     900 except BaseException as e:
# --> 901     with util.safe_reraise():
#     902         pool.logger.debug("Error on connect(): %s", e)
#     903 else:
#     904     # in SQLAlchemy 1.4 the first_connect event is not used by
#     905     # the engine, so this will usually not be set
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:897, in _ConnectionRecord.__connect(self)
#     895 try:
#     896     self.starttime = time.time()
# --> 897     self.dbapi_connection = connection = pool._invoke_creator(self)
#     898     pool.logger.debug("Created new connection %r", connection)
#     899     self.fresh = True
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py:646, in create_engine.<locals>.connect(connection_record)
#     643         if connection is not None:
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:622, in DefaultDialect.connect(self, *cargs, **cparams)
#     620 def connect(self, *cargs, **cparams):
#     621     # inherits the docstring from interfaces.Dialect.connect
# --> 622     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "dsstudents.skillbox.ru" (91.236.196.30), port 5432 failed: FATAL:  no pg_hba.conf entry for host "172.22.7.3", user "readonly", database "db_ds_students", no encryption
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3298, in Engine.raw_connection(self)
#    3277 """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279 The returned object is a proxied version of the DBAPI
#    (...)
#    3296
#    3297 """
# -> 3298 return self.pool.connect()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
#     447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1263 if not fairy:
# -> 1264     fairy = _ConnectionRecord.checkout(pool)
#    1266     if threadconns is not None:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     176 try:
# --> 177     return self._create_connection()
#     178 except:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:901, in _ConnectionRecord.__connect(self)
#     900 except BaseException as e:
# --> 901     with util.safe_reraise():
#     902         pool.logger.debug("Error on connect(): %s", e)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:897, in _ConnectionRecord.__connect(self)
#     896 self.starttime = time.time()
# --> 897 self.dbapi_connection = connection = pool._invoke_creator(self)
#     898 pool.logger.debug("Created new connection %r", connection)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py:646, in create_engine.<locals>.connect(connection_record)
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:622, in DefaultDialect.connect(self, *cargs, **cparams)
#     620 def connect(self, *cargs, **cparams):
#     621     # inherits the docstring from interfaces.Dialect.connect
# --> 622     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#
# OperationalError: connection to server at "dsstudents.skillbox.ru" (91.236.196.30), port 5432 failed: FATAL:  no pg_hba.conf entry for host "172.22.7.4", user "readonly", database "db_ds_students", no encryption
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 inspector = sqlalchemy.inspect(engine)
#       2 inspector.get_table_names()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\inspection.py:140, in inspect(subject, raiseerr)
#     138 elif reg is True:
#     139     return subject
# --> 140 ret = reg(subject)
#     141 if ret is not None:
#     142     return ret
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\reflection.py:313, in Inspector._engine_insp(bind)
#     311 @inspection._inspects(Engine)
#     312 def _engine_insp(bind: Engine) -> Inspector:  # type: ignore[misc]
# --> 313     return Inspector._construct(Inspector._init_engine, bind)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\reflection.py:246, in Inspector._construct(cls, init, bind)
#     243     cls = bind.dialect.inspector
#     245 self = cls.__new__(cls)
# --> 246 init(self, bind)
#     247 return self
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\reflection.py:257, in Inspector._init_engine(self, engine)
#     255 def _init_engine(self, engine: Engine) -> None:
#     256     self.bind = self.engine = engine
# --> 257     engine.connect().close()
#     258     self._op_context_requires_connect = True
#     259     self.dialect = self.engine.dialect
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3274, in Engine.connect(self)
#    3251 def connect(self) -> Connection:
#    3252     """Return a new :class:`_engine.Connection` object.
#    3253
#    3254     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3271
#    3272     """
# -> 3274     return self._connection_cls(self)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:148, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
# --> 148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#     151         raise
#     152 else:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2439, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2437 elif should_wrap:
#    2438     assert sqlalchemy_exception is not None
# -> 2439     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2440 else:
#    2441     assert exc_info[1] is not None
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 if connection is None:
#     145     try:
# --> 146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
#     148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3298, in Engine.raw_connection(self)
#    3276 def raw_connection(self) -> PoolProxiedConnection:
#    3277     """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279     The returned object is a proxied version of the DBAPI
#    (...)
#    3296
#    3297     """
# -> 3298     return self.pool.connect()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1256 @classmethod
#    1257 def _checkout(
#    1258     cls,
#    (...)
#    1261     fairy: Optional[_ConnectionFairy] = None,
#    1262 ) -> _ConnectionFairy:
#    1263     if not fairy:
# -> 1264         fairy = _ConnectionRecord.checkout(pool)
#    1266         if threadconns is not None:
#    1267             threadconns.current = weakref.ref(fairy)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     711     rec = cast(_ConnectionRecord, pool._do_get())
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#     716     dbapi_connection = rec.get_connection()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     673 self.__pool = pool
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:901, in _ConnectionRecord.__connect(self)
#     899     self.fresh = True
#     900 except BaseException as e:
# --> 901     with util.safe_reraise():
#     902         pool.logger.debug("Error on connect(): %s", e)
#     903 else:
#     904     # in SQLAlchemy 1.4 the first_connect event is not used by
#     905     # the engine, so this will usually not be set
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:897, in _ConnectionRecord.__connect(self)
#     895 try:
#     896     self.starttime = time.time()
# --> 897     self.dbapi_connection = connection = pool._invoke_creator(self)
#     898     pool.logger.debug("Created new connection %r", connection)
#     899     self.fresh = True
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py:646, in create_engine.<locals>.connect(connection_record)
#     643         if connection is not None:
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:622, in DefaultDialect.connect(self, *cargs, **cparams)
#     620 def connect(self, *cargs, **cparams):
#     621     # inherits the docstring from interfaces.Dialect.connect
# --> 622     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "dsstudents.skillbox.ru" (91.236.196.30), port 5432 failed: FATAL:  no pg_hba.conf entry for host "172.22.7.4", user "readonly", database "db_ds_students", no encryption
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
df = pd.read_sql("select TOP 5 * from ratings", connect)
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6948/252785355.py in <module>
# ----> 1 df = pd.read_sql("select TOP 5 from ratings", connect)
#       2 df.head(10)
#
# NameError: name 'connect' is not defined

# %% [markdown]
# ### Задача 6
#
# Сохраните первые 10000 записей датафрейма из предыдущей задачи в файл `result2.xlsx`, при сохранении задайте листу имя `MySheet`.
#
# (Примечание: для указания имени листа в файле Excel как при чтении, так и при записи используется параметр `sheet_name`)

# %%
#сохраняем первые 10000 строк
df.head(10000).to_excel('result2.xlsx', 
                        sheet_name='MySheet',
                        index=False  
                       )

# %% [markdown]
# ### Задача 7
#
# Определите количество документов в коллекции `users` в MongoDB. Если количество документов < 1000, то в следующей ячейке загрузите всё содержимое этой коллекции в список и выведите нулевой элемент этого списка на экран. Для подключения к MongoDB используйте строку подключения, указанную в следующей ячейке.

# %%
import pymongo
#сайт из урока не работает по причине обновления библиотек и python . Взял для работы один из общедоступных сервисов mongodb
conn = 'mongodb://mongo:CLnYghReBBXbijRHTtWsGpHWnDkmEMcN@switchback.proxy.rlwy.net:21133'

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\user0907\appdata\local\anaconda3\lib\site-packages (4.15.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\user0907\appdata\local\anaconda3\lib\site-packages (from pymongo) (2.8.0)

# %%
#создание экземпляра класса MongoClient с указанием строки подключения к базе данных MongoDB
client = pymongo.MongoClient(conn)

#выбор базы данных и коллекции
db = client['my_database']

# %%
#вызываем метод получения списка имен коллекций
db.list_collection_names()
# Out:
# ['users']

# %%
#cоздаем/выбираем коллекцию 'users'
collection = db['users']
collection
# Out:
# Collection(Database(MongoClient(host=['switchback.proxy.rlwy.net:21133'], document_class=dict, tz_aware=False, connect=True), 'my_database'), 'users')

# %%
#определяем количество документов в коллекции
doc_count = collection.count_documents({})
doc_count
# Out:
# 4

# %%
#если документов меньше 1000, загружаем всё содержимое
if doc_count < 1000:  
    #получаем все документы и преобразуем курсор в список
    all_documents = list(collection.find())
    
    #выводим документы коллекции
    one_doc = collection.find_one()
    print(one_doc)

    
else:
    print(f"Количество документов ({doc_count}) >= 1000, загрузка не выполняется.")
# Out:
# {'_id': ObjectId('68cc156af8bbe531d31bef0f'), 'name': 'Alice', 'age': 30, 'city': 'Berlin'}

# %% [markdown]
# ### Задача 8
#
# Преобразуйте список всех документов коллекции `users` из предыдущей задачи в pandas DataFrame и сохраните его содержимое в файл `result3.xlsx`.

# %%
#преобразуем курсор в список
head = collection.find()
my_list = list(head)
my_list
# Out:
# [{'_id': ObjectId('68cc156af8bbe531d31bef0f'),
#   'name': 'Alice',
#   'age': 30,
#   'city': 'Berlin'},
#  {'_id': ObjectId('68cc156af8bbe531d31bef10'),
#   'name': 'Bob',
#   'age': 25,
#   'city': 'London'},
#  {'_id': ObjectId('68cc156af8bbe531d31bef11'),
#   'name': 'Charlie',
#   'age': 35,
#   'city': 'New York'},
#  {'_id': ObjectId('68cc156af8bbe531d31bef12'),
#   'name': 'Diana',
#   'age': 28,
#   'city': 'Paris'}]

# %%
import pandas as pd
#записываем в датафрейм
df = pd.DataFrame(my_list)
df
# Out:
#                         _id     name  age      city
# 0  68cc156af8bbe531d31bef0f    Alice   30    Berlin
# 1  68cc156af8bbe531d31bef10      Bob   25    London
# 2  68cc156af8bbe531d31bef11  Charlie   35  New York
# 3  68cc156af8bbe531d31bef12    Diana   28     Paris

# %%
#сохраняем в эксель
df.to_excel('result3.xlsx', sheet_name = 'result3', index = 'Insex')

# %% [markdown]
# ## Дополнительные (необязательные) задачи
#
# ### Задача 9
#
# Используя данные SQL-таблицы `ratings`, для каждого пользователя (столбец `userid`) определите средний рейтинг, который этот пользователь поставил фильмам. Результат выведите на экран.
#
# Группировку проведите двумя способами: с помощью `GROUP BY` в строке запроса к БД и с использованием метода `groupby` в pandas.
#
# Для подключения к БД используйте строку подключения в следующей ячейке

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5432/db_ds_students'

# %% [markdown]
# ### Задача 10
#
# Объедините таблицы `ratings` и `keywords` по столбцам `movieid` (используйте левое объединение). Объединение проведите двумя способами: с помощью `LEFT JOIN` в строке запроса к БД и с использованием метода `merge` в pandas. Результат объединения загрузите в DataFrame и сохраните в файл `result4.csv`.
#
# Обратите внимание, что при объединении возможно дублирование столбцов. В результирующем датафрейме не должно быть таких дублированных столбцов.

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5432/db_ds_students'

# %% [markdown]
# ### Задача 11
#
# Используя объединенную таблицу из предыдущего задания, найдите все идентификаторы фильмов с тегом `africa` (но не `south africa` или любые другие). Список тегов в формате JSON записан в столбце `tags`.
