# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('ВыгрузкаТрудозатрат04_05_08.xlsx')
df
# Out:
#                                            Unnamed: 0  Количество строк  \
# 0                                               Склад               NaN
# 1                                         Исполнитель               NaN
# 2                                               Заказ               NaN
# 3                                                 SKU               NaN
# 4                               Отбор весового товара               NaN
# 5                                       Склад ГП База              11.0
# 6                        Елфимов Виталий Владимирович               1.0
# 7   Заказ на отгрузку 000246885 от 04.08.2025 17:2...               1.0
# 8   Пр.плав.сыр.ЯК.40%.колб.0,5кг/8кг.пл (нарезка)...               1.0
# 9                                     Ибрагим Мохамед               2.0
# 10  Заказ на отгрузку 000246822 от 04.08.2025 10:3...               1.0
# 11  Сыр.7Утра.Янтарный.30%.колб.8кг.пл; Пригоден; ...               1.0
# ...

# %%
series = df['Unnamed: 0'].value_counts()[df['Unnamed: 0'].value_counts(normalize=True) != 0]
#list_series = list(series.index)
#countries = df_kiva_loans['country'].value_counts()[df_kiva_loans['country'].value_counts(normalize=True)> 0.005]
#list_countries = list(countries.index)

# %%
#series = df[df['Unnamed: 0'] == 'Елфимов Виталий Владимирович']['Отбор абсолютные значения (кг)']
plt.hist(series)
# Out:
# (array([21.,  0.,  0.,  2.,  0.,  0.,  1.,  0.,  0.,  1.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(20,10))
plt.title("Количество", fontsize=16)
plt.tick_params(labelsize=14)
sns.barplot(y=series.index, x=series.values, alpha=0.6)
plt.show()

# %%
sns.pairplot(df, hue = 'Unnamed: 0',palette = 'rocket')
