# %%
import urllib.request as req
API_KEY = "83976e6bce8d4fe8980142043251509"

# %%
days = 3
url = f"http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q=Moscow&days={days}"

session = req.urlopen(url)
response = session.read().decode()

response
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 days = 3
#       2 url = f"http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q=Moscow&days={days}"
# ----> 4 session = req.urlopen(url)
#       5 response = session.read().decode()
#       7 response
#
# File ~\AppData\Local\anaconda3\Lib\urllib\request.py:189, in urlopen(url, data, timeout, context)
#     187 else:
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\anaconda3\Lib\urllib\request.py:495, in OpenerDirector.open(self, fullurl, data, timeout)
#     493 for processor in self.process_response.get(protocol, []):
#     494     meth = getattr(processor, meth_name)
# --> 495     response = meth(req, response)
#     497 return response
#
# ...

# %%
session.close()

# %%
with req.urlopen(url) as session:
  response1 = session.read().decode()

response1
# Out:
# '{"location":{"name":"Moscow","region":"Moscow City","country":"Russia","lat":55.75,"lon":37.62,"tz_id":"Europe/Moscow","localtime_epoch":1660754972,"localtime":"2022-08-17 19:49"},"current":{"last_updated_epoch":1660754700,"last_updated":"2022-08-17 19:45","temp_c":26.0,"temp_f":78.8,"is_day":1,"condition":{"text":"Sunny","icon":"//cdn.weatherapi.com/weather/64x64/day/113.png","code":1000},"wind_mph":11.9,"wind_kph":19.1,"wind_degree":70,"wind_dir":"ENE","pressure_mb":1018.0,"pressure_in":30.06,"precip_mm":0.0,"precip_in":0.0,"humidity":39,"cloud":0,"feelslike_c":25.7,"feelslike_f":78.2,"vis_km":10.0,"vis_miles":6.0,"uv":7.0,"gust_mph":6.5,"gust_kph":10.4},"forecast":{"forecastday":[{"date":"2022-08-17","date_epoch":1660694400,"day":{"maxtemp_c":32.7,"maxtemp_f":90.9,"mintemp_c":18.5,"mintemp_f":65.3,"avgtemp_c":25.0,"avgtemp_f":77.0,"maxwind_mph":10.3,"maxwind_kph":16.6,"totalprecip_mm":0.0,"totalprecip_in":0.0,"avgvis_km":10.0,"avgvis_miles":6.0,"avghumidity":44.0,"daily_will_it_r
# ...

# %%
import json

data = json.loads(response)
data
# Out:
# {'location': {'name': 'Moscow',
#   'region': 'Moscow City',
#   'country': 'Russia',
#   'lat': 55.75,
#   'lon': 37.62,
#   'tz_id': 'Europe/Moscow',
#   'localtime_epoch': 1660755934,
#   'localtime': '2022-08-17 20:05'},
#  'current': {'last_updated_epoch': 1660755600,
#   'last_updated': '2022-08-17 20:00',
#   'temp_c': 26.0,
#   'temp_f': 78.8,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 11.9,
#   'wind_kph': 19.1,
#   'wind_degree': 70,
#   'wind_dir': 'ENE',
#   'pressure_mb': 1018.0,
#   'pressure_in': 30.06,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 39,
#   'cloud': 0,
#   'feelslike_c': 26.1,
#   'feelslike_f': 78.9,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 7.0,
#   'gust_mph': 8.7,
#   'gust_kph': 14.0},
#  'forecast': {'forecastday': [{'date': '2022-08-17',
#     'date_epoch': 1660694400,
#     'day': {'maxtemp_c': 32.7,
# ...

# %%
len(data['forecast']['forecastday'])
# Out:
# 3

# %%
import pandas as pd

d = []

for i in range(days):
  d_outer = data['forecast']['forecastday'][i]
  d = d + d_outer['hour']
df = pd.DataFrame(d)
df.head()
# Out:
#    time_epoch              time  temp_c  temp_f  is_day  \
# 0  1660683600  2022-08-17 00:00    20.8    69.4       0
# 1  1660687200  2022-08-17 01:00    20.2    68.4       0
# 2  1660690800  2022-08-17 02:00    19.6    67.3       0
# 3  1660694400  2022-08-17 03:00    19.1    66.4       0
# 4  1660698000  2022-08-17 04:00    18.5    65.3       0
#
#                                            condition  wind_mph  wind_kph  \
# 0  {'text': 'Clear', 'icon': '//cdn.weatherapi.co...       7.2      11.5
# 1  {'text': 'Clear', 'icon': '//cdn.weatherapi.co...       7.4      11.9
# 2  {'text': 'Clear', 'icon': '//cdn.weatherapi.co...       7.2      11.5
# 3  {'text': 'Clear', 'icon': '//cdn.weatherapi.co...       6.9      11.2
# 4  {'text': 'Clear', 'icon': '//cdn.weatherapi.co...       7.4      11.9
#
#    wind_degree wind_dir  ...  dewpoint_f  will_it_rain  chance_of_rain  \
# 0          103      ESE  ...        55.2             0               0
# ...

# %%
df.shape
# Out:
# (72, 33)

# %%
df['temp_c'].min()
# Out:
# 18.5

# %%
df['temp_c'].max()
# Out:
# 32.7
