# %% [markdown]
# # Boosting
#
# ### Задание 1.
#
# Мы упоминали о том, что у функция потерь AdaBoost имеет более жесткий штраф по отношению к ошибкам классификации, чем другие часто используемые функции. Реализуйте функции logloss и AdaBoost loss, которые возвращают значения штрафов, и посмотрите по графику, насколько сильно они отличаются (примем x = y * y^).

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

x = np.linspace(-2, 1, 300)

def logloss(x):
    return np.log(1 + np.exp(-x))
   

def AdaLoss(x):
    return np.exp(-x)

plt.figure(figsize=(10, 4))
plt.plot(x, logloss(x), label='logloss')
plt.plot(x, AdaLoss(x), label='AdaLoss')
plt.legend(loc='best')
plt.xlabel('X')
plt.ylabel('Loss')

x_check = np.array([-2, 0, 2])
y_log = np.array([2.127, 0.693, 0.127])
y_ada = np.array([7.389, 1., 0.135])

assert np.allclose(logloss(x_check), y_log, atol=1e-3), f'Function logloss is not verified'
assert np.allclose(AdaLoss(x_check), y_ada, atol=1e-3), f'Function AdaLoss is not verified'

# %% [markdown]
# ### Задание 2.
#
# Когда дело доходит до оптимизации алгоритма, зачастую достаточно сложно подобрать сразу такие параметры, при которых качество классификатора было бы максимальным. В этом помогает либо опыт работы с различными методами, либо уже отмеченные другими специалистами взаимосвязи между количеством данных, самим алгоритмом, различными гиперпараметрами и т.п.
#
# В случае с бустингом было отмечено, что количество деревьев, при котором качество алгоритма максимально, зависит от темпа обучения: чем меньше темп, тем больше деревьев обычно требуется.
#
# В этом задании попробуйте последовательно подобрать такие гиперпараметры n_estimators и learning_rate в алгоритме GBC, чтобы accuracy была равна 1: сначала последовательно увеличивайте количество базовых деревьев, не меняя при этом learning_rate, а затем поменяйте количество деревьев снова на 1 и уже меняйте гиперпараметр learning_rate в пределах (0, 1), не включая границы. Если  accuracy не будет равна 1 при граничном значении learning_rate, добавляйте по одному базовому алгоритму и смотрите, что получится (напомним, что зависимость нелинейная - при значительном увеличении learning_rate количество деревьев может увеличиться всего на одну-две позиции.
#
# Сначала запустите следующий код со сгенерированными данными.

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

def plot(alg, data, target):
    xx, yy = np.meshgrid(np.linspace(0., 1., 100), np.linspace(0., 1., 100))
    Z = alg.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, levels=10, cmap=plt.cm.bwr, alpha=0.3)

    plt.scatter(data[:, 0], data[:, 1], s=20, c=targets)

    plt.xlim((0, 1))
    plt.ylim((0, 1))


np.random.seed(15)
data = np.random.rand(100, 2)
targets = np.empty(100)
targets[1 / data[:, 1] > 2] = 1
targets[1 / data[:, 1] < 3] = 0
targets[1 / data[:, 1] > 10] = 0
targets[[1, 3, 6, 15, 36]] = 1

plt.scatter(data[:, 0], data[:, 1], s=40, c=targets)

# %% [markdown]
# В следующей ячейке можете подбирать параметры алгоритма.

# %%
gbc = GradientBoostingClassifier(n_estimators=1, learning_rate=0.1) # подгонка гиперпараметров
model = gbc.fit(data, targets)
pred = gbc.predict(data)
plot(gbc, data, targets)

print(f'Accuracy: {accuracy_score(targets, pred)}')
# Out:
# Accuracy: 0.72

# %%
import numpy as np
for i in np.arange(0.1, 1.0, 0.1):
    for j in range(1, 21):
        gbc = GradientBoostingClassifier(n_estimators=j, learning_rate=i) # подгонка гиперпараметров
        model = gbc.fit(data, targets)
        pred = gbc.predict(data)
#plot(gbc, data, targets)

        print(f'Accuracy, при i = {i}, j = {j} : {accuracy_score(targets, pred)}')
#Выыод: опримальные параетры  learning_rate=0,3 - 0,9, n_estimators > 10, однако при увеличении learning_rate (шага градиентного спуска) - можно снижать количество деревьев
# Out:
# Accuracy, при i = 0.1, j = 1 : 0.72
# Accuracy, при i = 0.1, j = 2 : 0.72
# Accuracy, при i = 0.1, j = 3 : 0.72
# Accuracy, при i = 0.1, j = 4 : 0.97
# Accuracy, при i = 0.1, j = 5 : 0.97
# Accuracy, при i = 0.1, j = 6 : 0.97
# Accuracy, при i = 0.1, j = 7 : 0.97
# Accuracy, при i = 0.1, j = 8 : 0.97
# Accuracy, при i = 0.1, j = 9 : 0.98
# Accuracy, при i = 0.1, j = 10 : 0.97
# Accuracy, при i = 0.1, j = 11 : 0.99
# Accuracy, при i = 0.1, j = 12 : 0.99
# Accuracy, при i = 0.1, j = 13 : 0.98
# Accuracy, при i = 0.1, j = 14 : 0.98
# Accuracy, при i = 0.1, j = 15 : 0.98
# Accuracy, при i = 0.1, j = 16 : 0.98
# Accuracy, при i = 0.1, j = 17 : 0.98
# Accuracy, при i = 0.1, j = 18 : 0.98
# Accuracy, при i = 0.1, j = 19 : 0.98
# Accuracy, при i = 0.1, j = 20 : 0.98
# Accuracy, при i = 0.2, j = 1 : 0.72
# Accuracy, при i = 0.2, j = 2 : 0.97
# Accuracy, при i = 0.2, j = 3 : 0.98
# Accuracy, при i = 0.2, j = 4 : 0.97
# Accuracy, при i = 0.2, j = 5 : 0.99
# Accuracy, при i = 0.2, j = 6 : 0.99
# Accuracy, при i = 0.2, j = 7 : 0.98
# Accuracy, при i = 0.2, j = 8 : 0.98
# Accuracy, при i = 0.2, j = 9 : 0.98
# Accuracy, при i = 0.2, j = 10 : 0.98
# Accuracy, при i = 0.2, j = 11 : 0.98
# Accuracy, при i = 0.2, j = 12 : 0.98
# Accuracy, при i = 0.2, j = 13 : 0.98
# Accuracy, при i = 0.2, j = 14 : 0.99
# Accuracy, при i = 0.2, j = 15 : 0.99
# Accuracy, при i = 0.2, j = 16 : 0.99
# Accuracy, при i = 0.2, j = 17 : 1.0
# Accuracy, при i = 0.2, j = 18 : 1.0
# Accuracy, при i = 0.2, j = 19 : 1.0
# Accuracy, при i = 0.2, j = 20 : 1.0
# Accuracy, при i = 0.30000000000000004, j = 1 : 0.98
# Accuracy, при i = 0.30000000000000004, j = 2 : 0.98
# Accuracy, при i = 0.30000000000000004, j = 3 : 0.98
# Accuracy, при i = 0.30000000000000004, j = 4 : 0.99
# Accuracy, при i = 0.30000000000000004, j = 5 : 0.99
# Accuracy, при i = 0.30000000000000004, j = 6 : 0.98
# Accuracy, при i = 0.30000000000000004, j = 7 : 0.98
# Accuracy, при i = 0.30000000000000004, j = 8 : 0.98
# Accuracy, при i = 0.30000000000000004, j = 9 : 0.99
# Accuracy, при i = 0.30000000000000004, j = 10 : 1.0
# Accuracy, при i = 0.30000000000000004, j = 11 : 1.0
# Accuracy, при i = 0.30000000000000004, j = 12 : 1.0
# Accuracy, при i = 0.30000000000000004, j = 13 : 1.0
# Accuracy, при i = 0.30000000000000004, j = 14 : 1.0
# Accuracy, при i = 0.30000000000000004, j = 15 : 1.0
# Accuracy, при i = 0.30000000000000004, j = 16 : 1.0
# Accuracy, при i = 0.30000000000000004, j = 17 : 1.0
# Accuracy, при i = 0.30000000000000004, j = 18 : 1.0
# Accuracy, при i = 0.30000000000000004, j = 19 : 1.0
# Accuracy, при i = 0.30000000000000004, j = 20 : 1.0
# Accuracy, при i = 0.4, j = 1 : 0.98
# Accuracy, при i = 0.4, j = 2 : 0.99
# Accuracy, при i = 0.4, j = 3 : 0.99
# Accuracy, при i = 0.4, j = 4 : 0.99
# Accuracy, при i = 0.4, j = 5 : 0.99
# Accuracy, при i = 0.4, j = 6 : 0.98
# Accuracy, при i = 0.4, j = 7 : 0.99
# Accuracy, при i = 0.4, j = 8 : 1.0
# Accuracy, при i = 0.4, j = 9 : 1.0
# Accuracy, при i = 0.4, j = 10 : 1.0
# Accuracy, при i = 0.4, j = 11 : 1.0
# Accuracy, при i = 0.4, j = 12 : 1.0
# Accuracy, при i = 0.4, j = 13 : 1.0
# Accuracy, при i = 0.4, j = 14 : 1.0
# Accuracy, при i = 0.4, j = 15 : 1.0
# Accuracy, при i = 0.4, j = 16 : 1.0
# Accuracy, при i = 0.4, j = 17 : 1.0
# Accuracy, при i = 0.4, j = 18 : 1.0
# Accuracy, при i = 0.4, j = 19 : 1.0
# Accuracy, при i = 0.4, j = 20 : 1.0
# Accuracy, при i = 0.5, j = 1 : 0.98
# Accuracy, при i = 0.5, j = 2 : 0.99
# Accuracy, при i = 0.5, j = 3 : 0.99
# Accuracy, при i = 0.5, j = 4 : 0.99
# Accuracy, при i = 0.5, j = 5 : 0.99
# Accuracy, при i = 0.5, j = 6 : 0.99
# Accuracy, при i = 0.5, j = 7 : 1.0
# Accuracy, при i = 0.5, j = 8 : 1.0
# Accuracy, при i = 0.5, j = 9 : 1.0
# Accuracy, при i = 0.5, j = 10 : 1.0
# Accuracy, при i = 0.5, j = 11 : 1.0
# Accuracy, при i = 0.5, j = 12 : 1.0
# Accuracy, при i = 0.5, j = 13 : 1.0
# Accuracy, при i = 0.5, j = 14 : 1.0
# Accuracy, при i = 0.5, j = 15 : 1.0
# Accuracy, при i = 0.5, j = 16 : 1.0
# Accuracy, при i = 0.5, j = 17 : 1.0
# Accuracy, при i = 0.5, j = 18 : 1.0
# Accuracy, при i = 0.5, j = 19 : 1.0
# Accuracy, при i = 0.5, j = 20 : 1.0
# Accuracy, при i = 0.6, j = 1 : 0.98
# Accuracy, при i = 0.6, j = 2 : 0.99
# Accuracy, при i = 0.6, j = 3 : 1.0
# Accuracy, при i = 0.6, j = 4 : 0.99
# Accuracy, при i = 0.6, j = 5 : 0.99
# Accuracy, при i = 0.6, j = 6 : 1.0
# Accuracy, при i = 0.6, j = 7 : 1.0
# Accuracy, при i = 0.6, j = 8 : 1.0
# Accuracy, при i = 0.6, j = 9 : 1.0
# Accuracy, при i = 0.6, j = 10 : 1.0
# Accuracy, при i = 0.6, j = 11 : 1.0
# Accuracy, при i = 0.6, j = 12 : 1.0
# Accuracy, при i = 0.6, j = 13 : 1.0
# Accuracy, при i = 0.6, j = 14 : 1.0
# Accuracy, при i = 0.6, j = 15 : 1.0
# Accuracy, при i = 0.6, j = 16 : 1.0
# Accuracy, при i = 0.6, j = 17 : 1.0
# Accuracy, при i = 0.6, j = 18 : 1.0
# Accuracy, при i = 0.6, j = 19 : 1.0
# Accuracy, при i = 0.6, j = 20 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 1 : 0.98
# Accuracy, при i = 0.7000000000000001, j = 2 : 0.99
# Accuracy, при i = 0.7000000000000001, j = 3 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 4 : 0.99
# Accuracy, при i = 0.7000000000000001, j = 5 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 6 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 7 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 8 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 9 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 10 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 11 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 12 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 13 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 14 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 15 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 16 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 17 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 18 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 19 : 1.0
# Accuracy, при i = 0.7000000000000001, j = 20 : 1.0
# Accuracy, при i = 0.8, j = 1 : 0.98
# Accuracy, при i = 0.8, j = 2 : 0.99
# Accuracy, при i = 0.8, j = 3 : 1.0
# Accuracy, при i = 0.8, j = 4 : 0.99
# Accuracy, при i = 0.8, j = 5 : 1.0
# Accuracy, при i = 0.8, j = 6 : 1.0
# Accuracy, при i = 0.8, j = 7 : 1.0
# Accuracy, при i = 0.8, j = 8 : 1.0
# Accuracy, при i = 0.8, j = 9 : 1.0
# Accuracy, при i = 0.8, j = 10 : 1.0
# Accuracy, при i = 0.8, j = 11 : 1.0
# Accuracy, при i = 0.8, j = 12 : 1.0
# Accuracy, при i = 0.8, j = 13 : 1.0
# Accuracy, при i = 0.8, j = 14 : 1.0
# Accuracy, при i = 0.8, j = 15 : 1.0
# Accuracy, при i = 0.8, j = 16 : 1.0
# Accuracy, при i = 0.8, j = 17 : 1.0
# Accuracy, при i = 0.8, j = 18 : 1.0
# Accuracy, при i = 0.8, j = 19 : 1.0
# Accuracy, при i = 0.8, j = 20 : 1.0
# Accuracy, при i = 0.9, j = 1 : 0.98
# Accuracy, при i = 0.9, j = 2 : 1.0
# Accuracy, при i = 0.9, j = 3 : 1.0
# Accuracy, при i = 0.9, j = 4 : 1.0
# Accuracy, при i = 0.9, j = 5 : 1.0
# Accuracy, при i = 0.9, j = 6 : 1.0
# Accuracy, при i = 0.9, j = 7 : 1.0
# Accuracy, при i = 0.9, j = 8 : 1.0
# Accuracy, при i = 0.9, j = 9 : 1.0
# Accuracy, при i = 0.9, j = 10 : 1.0
# Accuracy, при i = 0.9, j = 11 : 1.0
# Accuracy, при i = 0.9, j = 12 : 1.0
# Accuracy, при i = 0.9, j = 13 : 1.0
# Accuracy, при i = 0.9, j = 14 : 1.0
# Accuracy, при i = 0.9, j = 15 : 1.0
# Accuracy, при i = 0.9, j = 16 : 1.0
# Accuracy, при i = 0.9, j = 17 : 1.0
# Accuracy, при i = 0.9, j = 18 : 1.0
# Accuracy, при i = 0.9, j = 19 : 1.0
# Accuracy, при i = 0.9, j = 20 : 1.0
