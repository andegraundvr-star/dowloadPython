# %%
import sqlalchemy

# %%
import platform
import sys

print("Архитектура системы:", platform.architecture())
print("Версия Python:", sys.version)
print("Платформа:", platform.platform())
# Out:
# Архитектура системы: ('64bit', 'WindowsPE')
# Версия Python: 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]
# Платформа: Windows-10-10.0.19045-SP0

# %%
#conn = 'mssql+pyodbc://username:VRA/user0907'
conn = 'mssql+pyodbc://db23/витринаданных?trusted_connection=yes&driver=SQL+Server'

# %%
# Создаем движок SQLAlchemy
connection_string = "mssql+pyodbc://db23/витринаданных?trusted_connection=yes&driver=SQL+Server"
engine = create_engine(connection_string)

# %%
#очистка
df = df.dropna(subset=['Площадка'])

# %%
import os
# Получить текущий рабочий каталог
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\user0907

# %%
import os
os.environ['HTTP_PROXY'] = 'http://VRA//user0907:Cegh%2A8j@proxy2.vra.local:4040'
os.environ['HTTPS_PROXY'] = 'http://VRA//user0907:Cegh%2A8j@proxy2.vra.local:4040'

# %%
import os
os.environ['HTTP_PROXY'] = ''
os.environ['HTTPS_PROXY'] = ''

# %%
set HTTP_PROXY=
set HTTPS_PROXY=
# Out:
#   Cell In[31], line 1
#     set HTTP_PROXY=
#         ^
# SyntaxError: invalid syntax

# %%
import socket
try:
    # Проверка разрешения доменного имени
    socket.gethostbyname('proxy2.vra.local')
    print("Доменное имя разрешается корректно")
except socket.gaierror:
    print("Ошибка разрешения доменного имени")
# Out:
# Доменное имя разрешается корректно

# %%
import requests
try:
    response = requests.get('http://google.com', 
                          proxies={'http': 'http://user0907:Cegh%2A8j@proxy2.vra.local:4040',
                                   'https': 'http://user0907:Cegh%2A8j@proxy2.vra.local:4040'},
                          timeout=5)
    print("Прокси доступен")
except Exception as e:
    print(f"Ошибка подключения к прокси: {e}")
# Out:
# Прокси доступен

# %%
# Проверка текущих прокси-настроек
import os
print("HTTP_PROXY:", os.environ.get('HTTP_PROXY'))
print("HTTPS_PROXY:", os.environ.get('HTTPS_PROXY'))
# Out:
# HTTP_PROXY: http://VRA//user0907:Cegh%2A8j@proxy2.vra.local:4040
# HTTPS_PROXY: http://VRA//user0907:Cegh%2A8j@proxy2.vra.local:4040

# %%
import sys
# !{sys.executable} -m pip install "C:\Users\user0907\AppData\Local\anaconda3\psycopg2-2.9.10-cp311-cp311-win_amd64.whl"
# Out:
# Processing c:\users\user0907\appdata\local\anaconda3\psycopg2-2.9.10-cp311-cp311-win_amd64.whl
# ...

# %%
# Проверка 1: Попытка импорта
try:
    import psycopg2
    print("✅ Модуль psycopg2 успешно импортирован!")
except ImportError as e:
    print(f"❌ Ошибка импорта: {e}")

# Проверка 2: Где находится модуль? (должен показать путь внутри Anaconda3)
import psycopg2
print(psycopg2.__file__)

# Проверка 3: Убедимся, что это тот же интерпретатор
import sys
print(sys.executable)
# Out:
# ✅ Модуль psycopg2 успешно импортирован!
# C:\Users\user0907\AppData\Local\anaconda3\envs\my_env\Lib\site-packages\psycopg2\__init__.py
# C:\Users\user0907\AppData\Local\anaconda3\envs\my_env\python.exe

# %%
import sys
# !{sys.executable} -m pip install "\Users\user0907\AppData\Local\anaconda3\missingno-0.5.2-py3-none-any.whl"
# Out:
# Processing c:\users\user0907\appdata\local\anaconda3\missingno-0.5.2-py3-none-any.whl
# ...
# missingno is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.

# %%
# Проверка 1: Попытка импорта
try:
    import missingno
    print("✅ Модуль missingno успешно импортирован!")
except ImportError as e:
    print(f"❌ Ошибка импорта: {e}")

# Проверка 2: Где находится модуль? (должен показать путь внутри Anaconda3)
import missingno
print(missingno.__file__)

# Проверка 3: Убедимся, что это тот же интерпретатор
import sys
print(sys.executable)
# Out:
# ✅ Модуль missingno успешно импортирован!
# C:\Users\user0907\AppData\Local\anaconda3\envs\my_env\Lib\site-packages\missingno\__init__.py
# C:\Users\user0907\AppData\Local\anaconda3\envs\my_env\python.exe

# %%
import sys
# !{sys.executable} -m pip install "C:\Users\user0907\AppData\Local\anaconda3\pymongo-4.15.1-cp311-cp311-win_amd64.whl"
# Out:
# Processing c:\users\user0907\appdata\local\anaconda3\pymongo-4.15.1-cp311-cp311-win_amd64.whl
# ...
#
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    ---------------------------------------- 2/2 [pymongo]
#
# ...

# %%
import sys
# !{sys.executable} -m pip install "C:\Users\user0907\AppData\Local\anaconda3\dnspython-2.8.0-py3-none-any.whl"
# Out:
# Processing c:\users\user0907\appdata\local\anaconda3\dnspython-2.8.0-py3-none-any.whl
# dnspython is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.

# %%
import pip._internal
print(pip._internal.pep425tags.get_supported())

# %%
# Проверка 1: Попытка импорта
try:
    import pymongo
    print("✅ Модуль pymongo успешно импортирован!")
except ImportError as e:
    print(f"❌ Ошибка импорта: {e}")

# Проверка 2: Где находится модуль? (должен показать путь внутри Anaconda3)
import missingno
print(missingno.__file__)

# Проверка 3: Убедимся, что это тот же интерпретатор
import sys
print(sys.executable)
# Out:
# ✅ Модуль pymongo успешно импортирован!
# C:\Users\user0907\AppData\Local\anaconda3\Lib\site-packages\missingno\__init__.py
# C:\Users\user0907\AppData\Local\anaconda3\python.exe
