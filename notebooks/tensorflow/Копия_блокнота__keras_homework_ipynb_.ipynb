# %% [markdown]
# # Домашнее задание
#
# В этом домашнем задании вам предстоит обучить модель классификации рукописных цифр на Tensorflow.
#
# Важным дополнительным требованием будет сохранение чекпоинтов на ваш гугл диск (не переживайтеЖ ниже будут подсказки, как это сделать). Это пригодится вам в дальнейшем при обучении более сложных моделей, на случай потери данных при неожиданном отключении Colab.

# %%
import tensorflow as tf
print(tf.__version__)
from google.colab import drive
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

 #tf.enable_eager_execution()
# Out:
# 2.19.0

# %% [markdown]
# ####Вспомогательный код

# %%
#@title
def show_mnist(images, labels, predicted_labels=None):
    plt.figure(figsize=(10,10))
    for i in range(16):
        plt.subplot(4,4, i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.gray)
        if predicted_labels is not None:
            title_obj = plt.title(f"Real: {labels[i]}. Pred: {predicted_labels[i]}")
            if labels[i] != predicted_labels[i]:
                plt.setp(title_obj, color='r')
        else:
            plt.title(f"Real label: {labels[i]}")

def show_progress(history: dict):
    plt.figure(figsize=(10, 5))
    ax1 = plt.subplot(1,2,1)
    plt.plot(history["accuracy"],label='train accuracy')
    plt.plot(history["val_accuracy"], label='test accuracy')
    ax2 = plt.subplot(1,2,2)
    plt.plot(history["loss"],label='train_loss')
    plt.plot(history["val_loss"],label='test_loss')

    ax1.legend(loc='best')
    ax2.legend(loc='best')
    plt.grid()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Загрузка данных

# %%
(x_train, y_train),(x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

show_mnist(x_train, y_train)
x_train = x_train.reshape((-1, 28*28)) # вытянули каждую картинку в вектор
x_test = x_test.reshape((-1, 28*28))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# прикрепим ваш гугл диск к виртуальной машине
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Путь до вашего гугл диска скорее всего выглядит так: /content/drive/My Drive/
# если эта клетка вызывает ошибку,
# измените путь согласно ! ls "/content/drive/"

path = Path("/content/drive/My Drive/Skillbox/model_1")
path.mkdir(exist_ok=True, parents=True) # папка создается на вашем гугл диске. вместе с "родителями"
assert path.exists()
cpt_filename = "best_checkpoint.keras"
cpt_path =str(path / cpt_filename)
# После выполнения этой клетки, в вашем гугл диске должна создаться папка: Skillbox/model_1
# убедитесь в этом

# %%
! pip install tensorflow
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input
import numpy as np
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %% [markdown]
# А весь код ниже вы реализуете самостоятельно! Вы уже к этому готовы :)
# Требования к модели:
# 1. Точность на тестовой части выборки >96%
# 2. Чекпоинт модели с лучшими параметрами должен быть сохранен у вас на гугл диске
# 3. Объект history, который получается из model.fit(...) должен содержать значения лосса и accuracy для трейна и теста

# %%
#создаем чекпоинт
checkpoint = tf.keras.callbacks.ModelCheckpoint(cpt_path, monitor='accuracy', verbose=1, save_best_only=True, mode='max')

# %%
# < YOUR CODE STARTS HERE >
inputlayer = tf.keras.layers.Input(shape = (784, ), name ="input")

l1 = Dense(32, activation='relu', name ="l1")
l1_output = l1(inputlayer)
l2 = Dense(32, activation='relu',  name = "l2")
l2_output = l2(l1_output)
#l3 = Dense(10, activation='relu', name = "l3")
#l3_output = l3(l2_output)

#выходной слой
output = Dense(10, activation='softmax', name = "output")(l2_output)
#собираем модель
model = tf.keras.Model(inputs=inputlayer, outputs=output, name="my_model")

#проверяем архитектуру
model.summary()
tf.keras.utils.plot_model(model, show_shapes = True)

#определяем оптимизатор
optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001)

#определяем loss
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

#обучаем
model.compile(optimizer=optimizer, loss=loss, metrics=["accuracy"])
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=60, verbose=1, batch_size=64, shuffle=True,
          callbacks=[checkpoint])



# < YOUR CODE ENDS HERE >
# Out:
# Model: "my_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ l1 (Dense)                      │ (None, 32)             │        25,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ l2 (Dense)                      │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,506 (103.54 KB)
#  Trainable params: 26,506 (103.54 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/60
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/nn.py:717: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 928/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7856 - loss: 0.7185
# Epoch 1: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7867 - loss: 0.7148 - val_accuracy: 0.9318 - val_loss: 0.2291
# Epoch 2/60
# 930/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9350 - loss: 0.2233
# Epoch 2: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9351 - loss: 0.2232 - val_accuracy: 0.9450 - val_loss: 0.1820
# Epoch 3/60
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9532 - loss: 0.1619
# Epoch 3: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9532 - loss: 0.1619 - val_accuracy: 0.9565 - val_loss: 0.1467
# Epoch 4/60
# 931/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9604 - loss: 0.1356
# Epoch 4: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9604 - loss: 0.1356 - val_accuracy: 0.9581 - val_loss: 0.1369
# Epoch 5/60
# 920/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9658 - loss: 0.1130
# Epoch 5: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9658 - loss: 0.1130 - val_accuracy: 0.9628 - val_loss: 0.1222
# Epoch 6/60
# 931/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9699 - loss: 0.0991
# Epoch 6: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9699 - loss: 0.0991 - val_accuracy: 0.9665 - val_loss: 0.1183
# Epoch 7/60
# 928/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9744 - loss: 0.0875
# Epoch 7: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9744 - loss: 0.0876 - val_accuracy: 0.9655 - val_loss: 0.1165
# Epoch 8/60
# 925/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9772 - loss: 0.0771
# Epoch 8: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9772 - loss: 0.0771 - val_accuracy: 0.9689 - val_loss: 0.1059
# Epoch 9/60
# 931/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9792 - loss: 0.0693
# Epoch 9: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9792 - loss: 0.0693 - val_accuracy: 0.9693 - val_loss: 0.1029
# Epoch 10/60
# 936/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9805 - loss: 0.0627
# Epoch 10: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9805 - loss: 0.0627 - val_accuracy: 0.9669 - val_loss: 0.1104
# Epoch 11/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9799 - loss: 0.0631
# Epoch 11: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9799 - loss: 0.0631 - val_accuracy: 0.9697 - val_loss: 0.1041
# Epoch 12/60
# 927/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9844 - loss: 0.0538
# Epoch 12: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9844 - loss: 0.0539 - val_accuracy: 0.9679 - val_loss: 0.1185
# Epoch 13/60
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9830 - loss: 0.0531
# Epoch 13: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9830 - loss: 0.0532 - val_accuracy: 0.9685 - val_loss: 0.1111
# Epoch 14/60
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9856 - loss: 0.0469
# Epoch 14: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9856 - loss: 0.0469 - val_accuracy: 0.9688 - val_loss: 0.1138
# Epoch 15/60
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9866 - loss: 0.0433
# Epoch 15: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9866 - loss: 0.0433 - val_accuracy: 0.9701 - val_loss: 0.1148
# Epoch 16/60
# 927/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9860 - loss: 0.0439
# Epoch 16: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9860 - loss: 0.0439 - val_accuracy: 0.9681 - val_loss: 0.1224
# Epoch 17/60
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9877 - loss: 0.0377
# Epoch 17: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9877 - loss: 0.0378 - val_accuracy: 0.9684 - val_loss: 0.1157
# Epoch 18/60
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0363
# Epoch 18: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9879 - loss: 0.0363 - val_accuracy: 0.9690 - val_loss: 0.1156
# Epoch 19/60
# 931/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9903 - loss: 0.0335
# Epoch 19: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9903 - loss: 0.0335 - val_accuracy: 0.9665 - val_loss: 0.1344
# Epoch 20/60
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9886 - loss: 0.0351
# Epoch 20: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9886 - loss: 0.0351 - val_accuracy: 0.9676 - val_loss: 0.1254
# Epoch 21/60
# 936/938 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9900 - loss: 0.0320
# Epoch 21: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9900 - loss: 0.0320 - val_accuracy: 0.9652 - val_loss: 0.1335
# Epoch 22/60
# 936/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9907 - loss: 0.0295
# Epoch 22: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9907 - loss: 0.0295 - val_accuracy: 0.9697 - val_loss: 0.1299
# Epoch 23/60
# 927/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9919 - loss: 0.0269
# Epoch 23: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9919 - loss: 0.0269 - val_accuracy: 0.9678 - val_loss: 0.1296
# Epoch 24/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9920 - loss: 0.0250
# Epoch 24: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9920 - loss: 0.0250 - val_accuracy: 0.9671 - val_loss: 0.1387
# Epoch 25/60
# 931/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9918 - loss: 0.0232
# Epoch 25: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9918 - loss: 0.0232 - val_accuracy: 0.9683 - val_loss: 0.1384
# Epoch 26/60
# 928/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9925 - loss: 0.0223
# Epoch 26: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9925 - loss: 0.0223 - val_accuracy: 0.9673 - val_loss: 0.1428
# Epoch 27/60
# 934/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9943 - loss: 0.0188
# Epoch 27: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9943 - loss: 0.0188 - val_accuracy: 0.9684 - val_loss: 0.1389
# Epoch 28/60
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9939 - loss: 0.0197
# Epoch 28: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9939 - loss: 0.0197 - val_accuracy: 0.9666 - val_loss: 0.1516
# Epoch 29/60
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9932 - loss: 0.0197
# Epoch 29: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9932 - loss: 0.0197 - val_accuracy: 0.9695 - val_loss: 0.1436
# Epoch 30/60
# 927/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9955 - loss: 0.0161
# Epoch 30: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9954 - loss: 0.0161 - val_accuracy: 0.9659 - val_loss: 0.1576
# Epoch 31/60
# 934/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9949 - loss: 0.0169
# Epoch 31: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9949 - loss: 0.0169 - val_accuracy: 0.9662 - val_loss: 0.1692
# Epoch 32/60
# 925/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9946 - loss: 0.0169
# Epoch 32: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9946 - loss: 0.0170 - val_accuracy: 0.9682 - val_loss: 0.1591
# Epoch 33/60
# 926/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9959 - loss: 0.0142
# Epoch 33: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9958 - loss: 0.0142 - val_accuracy: 0.9684 - val_loss: 0.1679
# Epoch 34/60
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9953 - loss: 0.0136
# Epoch 34: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9953 - loss: 0.0136 - val_accuracy: 0.9684 - val_loss: 0.1558
# Epoch 35/60
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9955 - loss: 0.0139
# Epoch 35: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9955 - loss: 0.0139 - val_accuracy: 0.9666 - val_loss: 0.1724
# Epoch 36/60
# 926/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9960 - loss: 0.0138
# Epoch 36: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9960 - loss: 0.0138 - val_accuracy: 0.9671 - val_loss: 0.1757
# Epoch 37/60
# 925/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9961 - loss: 0.0118
# Epoch 37: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9961 - loss: 0.0118 - val_accuracy: 0.9647 - val_loss: 0.1896
# Epoch 38/60
# 924/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9964 - loss: 0.0121
# Epoch 38: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9964 - loss: 0.0122 - val_accuracy: 0.9670 - val_loss: 0.1810
# Epoch 39/60
# 928/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9966 - loss: 0.0107
# Epoch 39: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9965 - loss: 0.0107 - val_accuracy: 0.9673 - val_loss: 0.1868
# Epoch 40/60
# 923/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9956 - loss: 0.0143
# Epoch 40: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9956 - loss: 0.0143 - val_accuracy: 0.9685 - val_loss: 0.1869
# Epoch 41/60
# 931/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9956 - loss: 0.0129
# Epoch 41: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9956 - loss: 0.0130 - val_accuracy: 0.9670 - val_loss: 0.1868
# Epoch 42/60
# 921/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9969 - loss: 0.0102
# Epoch 42: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9969 - loss: 0.0103 - val_accuracy: 0.9665 - val_loss: 0.1930
# Epoch 43/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9977 - loss: 0.0078
# Epoch 43: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9977 - loss: 0.0078 - val_accuracy: 0.9682 - val_loss: 0.1857
# Epoch 44/60
# 934/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.0073
# Epoch 44: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9980 - loss: 0.0073 - val_accuracy: 0.9683 - val_loss: 0.1969
# Epoch 45/60
# 927/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9963 - loss: 0.0109
# Epoch 45: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9963 - loss: 0.0109 - val_accuracy: 0.9651 - val_loss: 0.2119
# Epoch 46/60
# 933/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9967 - loss: 0.0106
# Epoch 46: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9967 - loss: 0.0106 - val_accuracy: 0.9668 - val_loss: 0.2135
# Epoch 47/60
# 936/938 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9973 - loss: 0.0090
# Epoch 47: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9973 - loss: 0.0090 - val_accuracy: 0.9674 - val_loss: 0.2074
# Epoch 48/60
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.0067
# Epoch 48: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9980 - loss: 0.0067 - val_accuracy: 0.9674 - val_loss: 0.2034
# Epoch 49/60
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9953 - loss: 0.0130
# Epoch 49: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9953 - loss: 0.0130 - val_accuracy: 0.9673 - val_loss: 0.2214
# Epoch 50/60
# 930/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9971 - loss: 0.0080
# Epoch 50: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9971 - loss: 0.0081 - val_accuracy: 0.9661 - val_loss: 0.2316
# Epoch 51/60
# 930/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9977 - loss: 0.0086
# Epoch 51: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9977 - loss: 0.0086 - val_accuracy: 0.9663 - val_loss: 0.2255
# Epoch 52/60
# 924/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9966 - loss: 0.0088
# Epoch 52: accuracy did not improve from 0.99737
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9966 - loss: 0.0088 - val_accuracy: 0.9676 - val_loss: 0.2153
# Epoch 53/60
# 926/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9977 - loss: 0.0068
# Epoch 53: accuracy improved from 0.99737 to 0.99782, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9977 - loss: 0.0068 - val_accuracy: 0.9695 - val_loss: 0.2117
# Epoch 54/60
# 932/938 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9983 - loss: 0.0057
# Epoch 54: accuracy did not improve from 0.99782
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9983 - loss: 0.0057 - val_accuracy: 0.9681 - val_loss: 0.2352
# Epoch 55/60
# 929/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9969 - loss: 0.0096
# Epoch 55: accuracy did not improve from 0.99782
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9969 - loss: 0.0096 - val_accuracy: 0.9657 - val_loss: 0.2288
# Epoch 56/60
# 935/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9976 - loss: 0.0067
# Epoch 56: accuracy did not improve from 0.99782
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9976 - loss: 0.0067 - val_accuracy: 0.9618 - val_loss: 0.2780
# Epoch 57/60
# 936/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0082
# Epoch 57: accuracy did not improve from 0.99782
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9973 - loss: 0.0082 - val_accuracy: 0.9664 - val_loss: 0.2273
# Epoch 58/60
# 930/938 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0083
# Epoch 58: accuracy did not improve from 0.99782
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9973 - loss: 0.0083 - val_accuracy: 0.9692 - val_loss: 0.2295
# Epoch 59/60
# 922/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9961 - loss: 0.0105
# Epoch 59: accuracy did not improve from 0.99782
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9961 - loss: 0.0105 - val_accuracy: 0.9672 - val_loss: 0.2462
# Epoch 60/60
# 930/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9974 - loss: 0.0072
# Epoch 60: accuracy did not improve from 0.99782
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9974 - loss: 0.0072 - val_accuracy: 0.9661 - val_loss: 0.2447

# %%
assert len(list(path.glob("*"))) != 0, f"Checkpoint dir {path}"
assert "accuracy" in history.history, "History object must contain Accuracy. Please, retrain with this metric"
assert "val_accuracy" in history.history, "Please, provide validation_data in model.fit."
assert np.max(history.history["val_accuracy"]) > 0.95, "Validation accuracy must be more than 0.95"
# Для старой версии (tf.__version__ == 1.x) запустить aseert-ы ниже:
# assert "acc" in history.history, "History object must contain Accuracy. Please, retrain with this metric"
# assert "val_acc" in history.history, "Please, provide validation_data in model.fit."
# assert np.max(history.history["val_acc"]) > 0.95, "Validation accuracy must be more than 0.95"
print("Training tests passed")
# Out:
# Training tests passed

# %% [markdown]
# Давайте посмотрим на графики обучения:

# %%
show_progress(history.history)

# %% [markdown]
# А теперь перейдем к загрузке модели. Если все реализовано правильно, то код ниже должен сработать без ошибок:

# %%
restored_model = tf.keras.models.load_model(cpt_path)
loss, acc = restored_model.evaluate(x_test, y_test)
print(f"Accuracy of restored model {acc*100 :.2f}%")
assert acc > 0.96
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9656 - loss: 0.2265
# Accuracy of restored model 96.95%

# %% [markdown]
# И, наконец, можно сравнить предсказания с реальными классами (с такой точностью найти ошибку будет сложно):

# %%
predicted_probs = restored_model.predict(x_test)
predicted_labels = np.argmax(predicted_probs, axis=1)
idxs = np.random.choice(np.arange(len(x_test)), 16, replace=False)
show_mnist(x_test[idxs].reshape((-1, 28, 28)), y_test[idxs], predicted_labels[idxs])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
