# %% [markdown]
# # Реализация обучения FCN
# В этом модуле мы создадим нашу первую FCN модель для задачи Семантической Сегментации. А также построим пайплайн обучения этой модели.
#
# Обучение такой модели на реальных данных займет достаточно длительное время. Поэтому мы будем обучаться на очень маленьком датасете, состоящем из одной картинки (и её зеркальной копии). При таком подходе мы столкнемся с проблемой переобучения ("запоминание" обучающей выборки и отсутствие обобщения), но ничего страшного. Нам лишь нужно будет протестировать, что пайплайн и модель работают корректно.

# %% [markdown]
# ### Загрузка необходимых библиотек
# Здесь мы загружаем различные библиотеки, включая TensoFlow.

# %%
import random
import imageio
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

import tensorflow as tf
#tf.enable_eager_execution()
print('TensorFlow version:', tf.__version__)
# Out:
# TensorFlow version: 2.19.0

# %% [markdown]
# # Подготовка датасета

# %% [markdown]
# ### Загрузка и подготовка входного изображения
# Файл 'me_256.png' должен находится в текущей директории. Вам необходимо загрузить его туда  самостоятельно, используя кнопку UPLOAD во вкладке Files в левой панели.

# %%
import os
print("Загружаю img")
img = imageio.imread('/content/sample_data/me_256.png')
img = img.astype(np.float32) / 255
_=plt.imshow(img)
# Out:
# Загружаю img
# /tmp/ipython-input-3613449071.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread('/content/sample_data/me_256.png')

# %%
import os
print("Загружаю img")
img = imageio.imread('/content/sample_data/me_gt_256.png')
img = img.astype(np.float32) / 255
_=plt.imshow(img)
# Out:
# Загружаю img
# /tmp/ipython-input-1991426343.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread('/content/sample_data/me_gt_256.png')

# %% [markdown]
# ### Загрузка и подготовка карты сегментации человек/фон
# То же самое касается файла 'me_gt_256.png'.
#
# После загрузки мы приводим 3 канала RGB к одному каналу путём усреднения.
#
# Это наша Ground-Truth карта сегментации, размеченная кем-то (мною) вручную.
# Значение `'0'` в ней означает класс "фон", значение `'1'` -- класс "человек"

# %%
gt = imageio.imread('/content/sample_data/me_gt_256.png')
gt = gt.astype(np.float32) / 255.
gt = np.mean(gt, axis=2)[..., None]
_=plt.imshow(gt[...,0])
# Out:
# /tmp/ipython-input-512321571.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   gt = imageio.imread('/content/sample_data/me_gt_256.png')

# %% [markdown]
# ### Подготовка обучающего датасета
# Наша цель создать и протестировать пайплайн для обучения FCN модели, включая данные, модель, лосс и т.д.
#
# Поэтому для простоты эксперимента возьмем очень простой датасет, состоящий из двух изображений: загруженная картинка и её зеркально отраженная копия.
#
# Индексирование `'::-1'` означает взять все элементы в обратном порядке.
#
# При обучении на таком маленьком датасете модель переобучится, но в данном примере нас это не будет беспокоить. Наша цель - отладить пайплайн, поэтому тестировать будем на том же, на чём и обучались.

# %%
train_x = np.stack((img, img[:,::-1,:]))
train_y = np.stack((gt, gt[:,::-1,:]))

plt.imshow(train_x[0]), plt.show()
plt.imshow(train_y[0][...,0]), plt.show()
plt.imshow(train_x[1]), plt.show()
plt.imshow(train_y[1][...,0]), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7eae12fbc230>, None)

# %% [markdown]
# # Пайплайн обучения FCN

# %% [markdown]
# ### Создание FCN модели
# В TensorFlow есть несколько способов создать нейросетевую модель. Ранее мы создавали модель с помощью `tf.keras.Sequential`, где нужно было просто перечислить последовательность слоёв. Кроме того, вы знакомы с функциональным способом создания модели, в котором мы строим наш вычислительных граф, соединяя различные операции, что даёт нам возможность получить произвольный граф из слоёв, а не только линейный (последовательный), как в случае Sequential.
#
# Есть и третий способ создать модель -- создать свой собственный класс, наследованный от `tf.keras.Model`. Это самый гибкий способ, при таком подходе можно создавать абсолютно любые графы, в том числе динамические, то есть с произвольным потоком управления (control flow). В такой граф можно вставлять проверки условий, циклы и практически любые функции из Питона и TensorFlow.
#
# Организовать такой класс мы можем произвольным образом, но как минимум нам надо реализовать конструктор `__init__()` и функцию для прямого распространения (инференса) нашего графа `call()`. В конструкторе мы создаём нужные нам слои и другие необходимые вещи. А в методе `call()` используем эти слои для вычисления прямого распространения (инференса) нашей сети. То есть именно в функции `call()` задается архитектура нашей нейронной сети путём написания кода в стиле обычного Питона.
#
# Так как наш граф является динамическим и в TensorFlow мы включили режим жадного (eager) выполнения, написанный в функции `call()` код (то есть вычисления всех слоёв) будет выполняться прямо в момент вызова `call()` (не раньше и не позже), так же как и в обычном Питоне.
#
# В результате вычисления слоёв (прохода по динамическому графу) нас интересуют две вещи. Первая вещь - финальный выход нейронной сети (то, что возвращает функция `call()`). Если нас не интересуют промежуточные данные (что было на выходе первого, второго слоя и.т.д) и эти тензоры больше нигде не используются, мы можем записывать выход каждого слоя в переменную с тем же именем (например, `out`) и передавать её на вход в следующий слой. Вторая вещь - запоминание пути, по которому шло прямое распространение, чтобы TensorFlow смог сделать backpropagation по "обратному" пути. Эта вторая вещь делается в TensorFlow автоматически, если мы используем так называемую градиентную ленту (Gradient Tape) или же используем функцию `fit()` из Keras для обучения модели (этот способ мы использовали ранее).
#
# Созданный нами класс по сути то же является "слоем", так что мы можем использовать его как "слой" в каких-то других нейросетях. Таким образом можно создавать сложный нейронные сети модульно, сначала простые модели, а потом более сложные модули на их основе. Это нам пригодится в будущем. А пока что создадим довольно простую FCN с участием Свёрточных слоёв, Pooling слоёв и Upscale.
#
# В качестве Upscale будем использовать билинейную интерполяцию. Для этого важно использовать функцию из TensorFlow (`tf.image.resize`), а не аналоги из Питона, чтобы для этой функции можно было посчитать backpropagation. В TensorFlow есть аналоги практически все математических и других питон функций, которые могут потребоваться при создании произвольных нейросетей.
#
# **[ЗАДАНИЕ 1]** Вопрос: В конструкторе нашей модели мы создали отдельный экземпляр для каждого свёрточного слоя. А почему мы создали лишь один экземпляр Pooling слоя, несмотря на то, что в сети у нас есть несколько Pooling слоёв?

# %%
class Model(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.conv1 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv2 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv3 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv4 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv5 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv6 = tf.keras.layers.Conv2D(1, (3, 3), padding='same', activation=None)
        self.pool = tf.keras.layers.MaxPool2D((2, 2))

    def call(self, x):
        out = self.conv1(x)
        out = self.conv2(out)
        out = self.pool(out)
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.pool(out)
        out = self.conv5(out)
        out = self.conv6(out)
        out = tf.image.resize(out, (x.shape[1], x.shape[2]), tf.image.ResizeMethod.BILINEAR)
        out = tf.nn.sigmoid(out)
        return out

model = Model()

# %% [markdown]
# ### Обучение FCN модели
# В конце предыдущего блока мы создали объект `model` как экземпляр нашего класса `Model`.
# Обучить такую модель теперь можно точно так же, как и любую другу модель в TensorFlow.
#
# Так как на выходе в каждом пикселе у нас лишь одно значение (бинарная классификация "фон"/"человек"), то в сети в самом конце у нас использовалась функция `sigmoid`, выход которой в диапазоне от 0 до 1. Ground-Truth наш так же имеет одно значение в каждом пикселе (0 или 1).
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9985 - loss: 0.0039
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9985 - loss: 0.0039
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9985 - loss: 0.0038
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9985 - loss: 0.0038
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9985 - loss: 0.0037
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9986 - loss: 0.0037
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9985 - loss: 0.0037
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9986 - loss: 0.0036
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9986 - loss: 0.0036
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9987 - loss: 0.0035
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9987 - loss: 0.0035
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9987 - loss: 0.0035
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9987 - loss: 0.0034
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9987 - loss: 0.0034
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9988 - loss: 0.0034
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9988 - loss: 0.0033
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9988 - loss: 0.0033
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9989 - loss: 0.0032
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9989 - loss: 0.0032
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9989 - loss: 0.0032
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9989 - loss: 0.0031
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9989 - loss: 0.0031
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9989 - loss: 0.0031
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9990 - loss: 0.0030
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9990 - loss: 0.0030
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9990 - loss: 0.0030
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9990 - loss: 0.0029
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9990 - loss: 0.0029
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9990 - loss: 0.0029
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9990 - loss: 0.0028
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9990 - loss: 0.0028
# CPU times: user 13.6 s, sys: 1.87 s, total: 15.5 s
# Wall time: 22.7 s

# %%
plt.figure(figsize=(8, 5))
plt.plot(hist.history['loss'], label='Train Loss', linewidth=2)
if 'val_loss' in hist.history:
    plt.plot(hist.history['val_loss'], label='Val Loss', linewidth=2)

plt.title('Loss vs Эпохи', fontsize=14)
plt.xlabel('Эпоха', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
hist2 = model.fit(
    train_x,
    train_y,
    epochs=100,
    batch_size=32,           #увеличим с 1 до 32-256
    validation_split=0.2,    #добавим автоматическое разделение на train/val
    verbose=1                #оставим для визуализации прогресса
)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9990 - loss: 0.0028 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9990 - loss: 0.0028 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9990 - loss: 0.0028 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9989 - loss: 0.0028 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9990 - loss: 0.0028 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9990 - loss: 0.0028 - val_accuracy: 0.9989 - val_loss: 0.0029
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9991 - loss: 0.0028 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9990 - loss: 0.0028 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9991 - loss: 0.0028 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9990 - loss: 0.0027 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9990 - loss: 0.0027 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9990 - loss: 0.0027 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9990 - loss: 0.0027 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9990 - loss: 0.0027 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9991 - loss: 0.0027 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9990 - loss: 0.0027 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9990 - loss: 0.0027 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9990 - loss: 0.0026 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9990 - loss: 0.0026 - val_accuracy: 0.9989 - val_loss: 0.0028
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9991 - loss: 0.0026 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9990 - loss: 0.0026 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9990 - loss: 0.0026 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9990 - loss: 0.0026 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9990 - loss: 0.0026 - val_accuracy: 0.9989 - val_loss: 0.0028
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9990 - loss: 0.0026 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9991 - loss: 0.0026 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9991 - loss: 0.0026 - val_accuracy: 0.9989 - val_loss: 0.0028
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9991 - loss: 0.0026 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9991 - loss: 0.0026 - val_accuracy: 0.9989 - val_loss: 0.0028
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9989 - val_loss: 0.0028
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9989 - val_loss: 0.0028
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9989 - val_loss: 0.0028
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9989 - val_loss: 0.0028
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9989 - val_loss: 0.0028
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9989 - val_loss: 0.0028
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9989 - val_loss: 0.0028
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9990 - val_loss: 0.0028
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9989 - val_loss: 0.0028
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9989 - val_loss: 0.0028
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9989 - val_loss: 0.0028
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9989 - val_loss: 0.0029
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9989 - val_loss: 0.0029
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9989 - val_loss: 0.0029
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9989 - val_loss: 0.0029
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9989 - val_loss: 0.0029
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9989 - val_loss: 0.0029
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 577ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9989 - val_loss: 0.0029
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9989 - val_loss: 0.0029
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9989 - val_loss: 0.0029
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9991 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9992 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9992 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9991 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9992 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9991 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9991 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9991 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9991 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9989 - val_loss: 0.0029
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0030
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9991 - loss: 0.0024 - val_accuracy: 0.9989 - val_loss: 0.0029
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9992 - loss: 0.0024 - val_accuracy: 0.9990 - val_loss: 0.0030
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9991 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9992 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9991 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9991 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9991 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9991 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9991 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9992 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9992 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9992 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0029

# %%
#проверяем историю обучения
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

#график точности
axes[0].plot(hist2.history['accuracy'], label='Train')
axes[0].plot(hist2.history['val_accuracy'], label='Val')
axes[0].set_title('Точность (Accuracy)')
axes[0].set_xlabel('Эпоха')
axes[0].legend()

#график потерь
axes[1].plot(hist2.history['loss'], label='Train')
axes[1].plot(hist2.history['val_loss'], label='Val')
axes[1].set_title('Потери (Loss)')
axes[1].set_xlabel('Эпоха')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Результат предсказания на входной картинке
# Протестируем результат работы модели `model` на входной картинке `img`.
#
# Не забудем приклеить дополнительное батч измерение с помощью `[None, ...]`, а потом отрезать его с помощью `[0, ...]`

# %%
out = model.predict(img[None, ...])[0, ...]
_=plt.imshow(out[...,0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step

# %%
plt.figure(figsize=(8, 6))
plt.imshow(img)
plt.axis('off')
plt.title('Исходное цветное фото')
plt.show()

# %% [markdown]
# ### Результат предсказания для всех картинок
# По непрерывному предсказанию FCN модели (от нуля до единицы) получим дискретную карту сегментации помощью порога (0.5).
#
# Далее наложим полученную карту сегментации (после преобразования в цветную картинку с колормапом jet) на исходную картинку. Сделаем это для обоих объектов в обучающей выборке.

# %%
for sample in train_x:
    out = model.predict(sample[None, ...])

    seg_map = (out[0, ..., 0]>0.5).astype(np.float32)
    seg_map_clr = plt.get_cmap('viridis')(seg_map)[..., :3]
    plt.imshow(sample*0.5 + seg_map_clr*0.5)
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['accuracy'])

# %%
plt.plot(hist2.history['loss'])
plt.plot(hist2.history['accuracy'])
