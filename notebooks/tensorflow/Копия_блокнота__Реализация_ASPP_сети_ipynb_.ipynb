# %% [markdown]
# # Реализация ASPP сети
# В этом уроке мы создадим еще еще одну сегментационную FCN модель на основе блока ASPP (Atrous Spatial Pyramid Pooling), который основан на дилатационных свёртках (Atrous Conv, Dilated Conv)

# %% [markdown]
# ### Загрузка необходимых библиотек
# Здесь мы загружаем различне библиотеки, включая TensoFlow.

# %%
import numpy as np

import tensorflow as tf
print('TensorFlow version:', tf.__version__)
# Out:
# TensorFlow version: 2.19.0

# %% [markdown]
# ### Создание ASPP модели
# В этом примере мы будем создавать модель `ASPPNet` через собственный класс, наследованный от `tf.keras.Model`. Кроме того, будем использовать возможность модульного создания нейросетей. Сначала создадим отдельно модель для ASPP блока (блок, который содержит только дилатационные свёртки и применяется между энкодером и декодером), которая по сути будет являться самостоятельным слоем. А затем создадим финальную модель `ASPPNet`, в который `ASPPBlock` будет использоваться как слой между Энкодером и Декодером.
#
# В ASPP блоке (`ASPPBlock`) ко входному тензору параллельно применяются обычная свёртка 1x1 и несколько дилатационных свёрток. Затем все эти резульаты конкатенируются. Далее "перемешиваем" каналы полученного тензора с помощью еще одной свёртки 1x1.
#
# В финальной ASPP модели (`ASPPNet`) в качестве Энкодера будем использовать стандартные свёртки и пулинги. Далее в боттлнеке (в середине сети) применим слой ASPPBlock. А в Декодере будем использовать более простую архитектуру: меньше свёрток, повышение размерности с помощью двух билинейных интерполяций (`tf.image.resize`). Кроме того, в сети присутствуют две проброшенные связи.

# %%
class ASPPBlock(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.conv1 = tf.keras.layers.Conv2D(256, (1, 1), padding='same', activation='relu')
        self.conv2 = tf.keras.layers.Conv2D(256, (3, 3), dilation_rate=6, padding='same', activation='relu')
        self.conv3 = tf.keras.layers.Conv2D(256, (3, 3), dilation_rate=12, padding='same', activation='relu')
        self.conv4 = tf.keras.layers.Conv2D(256, (3, 3), dilation_rate=18, padding='same', activation='relu')
        self.conv5 = tf.keras.layers.Conv2D(256, (1, 1), padding='same', activation='relu')

    def call(self, inp, is_training=False):
        out1 = self.conv1(inp)
        out2 = self.conv2(inp)
        out3 = self.conv3(inp)
        out4 = self.conv4(inp)
        out = tf.concat([out1, out2, out3, out4], axis=3)
        out = self.conv5(out)
        return out

class ASPPNet(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.conv1 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv2 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv3 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv4 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv5 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv6 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv7 = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')
        self.conv8 = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')
        self.conv9 = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')
        self.conv10 = tf.keras.layers.Conv2D(512, (3, 3), padding='same', activation='relu')

        self.conv11 = tf.keras.layers.Conv2D(48, (1, 1), padding='same', activation='relu')
        self.conv12 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv13 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv14 = tf.keras.layers.Conv2D(1, (1, 1), padding='same', activation=None)

        self.maxpool = tf.keras.layers.MaxPooling2D((2, 2), (2, 2), padding='same')

        self.aspp = ASPPBlock()

    def call(self, x):

        out = self.conv1(x)
        out = self.conv2(out)
        out = self.maxpool(out)
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.maxpool(out)
        out = self.conv5(out)
        out = self.conv6(out)
        out_enc_mid = out
        out = self.maxpool(out)
        out = self.conv7(out)
        out = self.conv8(out)
        out = self.maxpool(out)
        out = self.conv9(out)
        out = self.conv10(out)

        out = self.aspp(out)

        out = tf.image.resize(out, tf.shape(out_enc_mid)[1:3], tf.image.ResizeMethod.BILINEAR)

        out_enc_mid = self.conv11(out_enc_mid)

        out = tf.concat([out, out_enc_mid], axis=3)

        out = self.conv12(out)
        out = self.conv13(out)
        out = self.conv14(out)

        out = tf.image.resize(out, tf.shape(x)[1:3], tf.image.ResizeMethod.BILINEAR)
        out = tf.nn.sigmoid(out)
        return out

model = ASPPNet()

# %% [markdown]
# ### Задания

# %% [markdown]
# **[ЗАДАНИЕ 1]** Вопрос: почему в ASPPNet в первой билинейной интерполяции (`tf.image.resize`) в качестве желаемого выходного размера тензора мы используем размер тензора `out_enc_mid`?

# %%
#для сохранения глобального контекста и пространственных мелких деталей

# %% [markdown]
# **[ЗАДАНИЕ 2]** Реализуйте пайплайн обучения для модели ASPPNet: подготовка данных, лосс, обучение, тестирование. Используйте материалы из предыдущего практического урока. Обучите модель и сравните время обучения с временем обучения более простых версий FCN из предыдущих уроков.

# %%
import random
import imageio
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import os
print("Загружаю img")
img = imageio.imread('/content/sample_data/me_256.png')
img = img.astype(np.float32) / 255
_=plt.imshow(img)
# Out:
# Загружаю img
# /tmp/ipython-input-147745261.py:9: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread('/content/sample_data/me_256.png')

# %%
import os
print("Загружаю img")
img = imageio.imread('/content/sample_data/me_gt_256.png')
img = img.astype(np.float32) / 255
_=plt.imshow(img)
# Out:
# Загружаю img
# /tmp/ipython-input-1991426343.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread('/content/sample_data/me_gt_256.png')

# %%
gt = imageio.imread('/content/sample_data/me_gt_256.png')
gt = gt.astype(np.float32) / 255.
gt = np.mean(gt, axis=2)[..., None]
_=plt.imshow(gt[...,0])
# Out:
# /tmp/ipython-input-512321571.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   gt = imageio.imread('/content/sample_data/me_gt_256.png')

# %%
train_x = np.stack((img, img[:,::-1,:]))
train_y = np.stack((gt, gt[:,::-1,:]))

plt.imshow(train_x[0]), plt.show()
plt.imshow(train_y[0][...,0]), plt.show()
plt.imshow(train_x[1]), plt.show()
plt.imshow(train_y[1][...,0]), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7bd8c176d7c0>, None)

# %%
# %%time
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')
hist = model.fit(train_x,train_y, epochs=100, batch_size=1)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 29s 119ms/step - accuracy: 0.4475 - loss: 0.6666
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7702 - loss: 2.5844
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8971 - loss: 0.6305
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8159 - loss: 0.6494
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8159 - loss: 0.5813
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8159 - loss: 0.4956
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8159 - loss: 0.3846
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8159 - loss: 0.3800
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8482 - loss: 0.2738
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9529 - loss: 0.1474
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9598 - loss: 0.0909
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9720 - loss: 0.0785
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9788 - loss: 0.0559
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9845 - loss: 0.0363
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9884 - loss: 0.0318
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9881 - loss: 0.0268
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9920 - loss: 0.0210
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9924 - loss: 0.0178
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9934 - loss: 0.0160
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9937 - loss: 0.0153
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9937 - loss: 0.0152
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9939 - loss: 0.0147
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9946 - loss: 0.0134
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9949 - loss: 0.0124
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9952 - loss: 0.0121
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9954 - loss: 0.0113
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9955 - loss: 0.0111
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9957 - loss: 0.0105
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9959 - loss: 0.0102
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9959 - loss: 0.0101
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9961 - loss: 0.0098
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9963 - loss: 0.0091
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9965 - loss: 0.0088
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9967 - loss: 0.0085
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9965 - loss: 0.0086
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9968 - loss: 0.0080
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9968 - loss: 0.0083
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9966 - loss: 0.0082
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9969 - loss: 0.0077
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9969 - loss: 0.0078
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9968 - loss: 0.0077
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9970 - loss: 0.0073
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9970 - loss: 0.0073
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9973 - loss: 0.0070
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9971 - loss: 0.0072
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9972 - loss: 0.0069
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9975 - loss: 0.0068
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9974 - loss: 0.0067
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9975 - loss: 0.0066
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9975 - loss: 0.0065
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9977 - loss: 0.0064
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9977 - loss: 0.0063
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9976 - loss: 0.0063
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9975 - loss: 0.0062
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9977 - loss: 0.0061
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9976 - loss: 0.0061
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9972 - loss: 0.0066
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9976 - loss: 0.0060
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9976 - loss: 0.0059
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9977 - loss: 0.0059
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9977 - loss: 0.0058
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9977 - loss: 0.0057
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9975 - loss: 0.0060
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9977 - loss: 0.0057
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9979 - loss: 0.0055
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9969 - loss: 0.0072
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9965 - loss: 0.0082
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9973 - loss: 0.0063
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9977 - loss: 0.0059
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9975 - loss: 0.0060
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9976 - loss: 0.0061
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9976 - loss: 0.0060
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9977 - loss: 0.0058
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9978 - loss: 0.0057
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9978 - loss: 0.0056
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9978 - loss: 0.0054
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9979 - loss: 0.0054
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9978 - loss: 0.0053
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9979 - loss: 0.0053
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9979 - loss: 0.0051
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9980 - loss: 0.0051
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9980 - loss: 0.0050
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9981 - loss: 0.0049
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9982 - loss: 0.0048
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9981 - loss: 0.0048
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9981 - loss: 0.0047
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9981 - loss: 0.0047
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9981 - loss: 0.0048
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9982 - loss: 0.0045
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9982 - loss: 0.0046
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9982 - loss: 0.0046
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9979 - loss: 0.0050
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9983 - loss: 0.0043
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9984 - loss: 0.0043
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9978 - loss: 0.0051
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9980 - loss: 0.0047
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9978 - loss: 0.0051
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9983 - loss: 0.0043
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9981 - loss: 0.0047
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9977 - loss: 0.0053
# CPU times: user 28.4 s, sys: 3.83 s, total: 32.3 s
# Wall time: 43.2 s

# %%
plt.plot(hist.history['loss'])

# %%
out = model.predict(img[None, ...])
_=plt.imshow(out[0, ..., 0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %%
for sample in train_x:
    out = model.predict(sample[None, ...])
    seg_map = (out[0, ..., 0]>0.5).astype(np.float32)
    seg_map_clr = plt.get_cmap('jet')(seg_map)[..., :3]
    plt.imshow(sample*0.5 + seg_map_clr*0.5)
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
